# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy as sp
import csv
import matplotlib.patches as mpatches
import pylab as pb
import matplotlib.ticker as mtick
from matplotlib import cm
from numpy import linspace
from csv import reader
from matplotlib import pyplot
import matplotlib.colors as colors
import bokeh as bk
import pandas as pd

# %%
bias70 = []
current70 = []
leakage70 = []

with open('70_cycles_5Vgt_1Vs_sweep_rate1.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        bias70.append(float(row[0]))
        current70.append(float(row[1]))
        leakage70.append(float(row[2]))

# %%
bias50f = []
current50f = []
leakage50f = []

with open('first_50_cycles_5Vgt_21Vs_sweep_rate.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        bias50f.append(float(row[0]))
        current50f.append(float(row[1]))
        leakage50f.append(float(row[2]))
       
    
bias50s = []
current50s = []
leakage50s = []

with open('second_50_cycles_5Vgt_21Vs_sweep_rate.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        bias50s.append(float(row[0]))
        current50s.append(float(row[1]))
        leakage50s.append(float(row[2]))    
        

bias50t = []
current50t = []
leakage50t = []

with open('third_50_cycles_5Vgt_21Vs_sweep_rate.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        bias50t.append(float(row[0]))
        current50t.append(float(row[1]))
        leakage50t.append(float(row[2]))
        
        
bias50q = []
current50q = []
leakage50q = []

with open('fourth_50_cycles_5Vgt_21Vs_sweep_rate.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        bias50q.append(float(row[0]))
        current50q.append(float(row[1]))
        leakage50q.append(float(row[2]))

# %%
bias232 = []
current232 = []
leakage232 = []

with open('100_cycles_5Vgt_2.32Vs_sweep_rate.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        bias232.append(float(row[0]))
        current232.append(float(row[1]))
        leakage232.append(float(row[2]))
        
        
bias29 = []
current29 = []
leakage29 = []

with open('100_cycles_5Vgt_2.9Vs_sweep_rate.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        bias29.append(float(row[0]))
        current29.append(float(row[1]))
        leakage29.append(float(row[2]))
       
    
bias137 = []
current137 = []
leakage137 = []

with open('12_cycles_5Vgt_1.37Vs_sweep_rate.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        bias137.append(float(row[0]))
        current137.append(float(row[1]))
        leakage137.append(float(row[2]))


bias019 = []
current019 = []
leakage019 = []

with open('8_cycles_5Vgt_0.19Vs_sweep_rate.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        bias019.append(float(row[0]))
        current019.append(float(row[1]))
        leakage019.append(float(row[2]))
        
crnt = []
gt = []
lk = []

with open('gate_sweep_after_everything.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        crnt.append(float(row[0]))
        gt.append(float(row[1]))
        lk.append(float(row[2]))
        
post_bias = []
post_current = []
post_leakage = []

with open('post_everything_IV.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        post_bias.append(float(row[0]))
        post_current.append(float(row[1]))
        post_leakage.append(float(row[2]))

# %%
bia444 = []
curren444 = []
leakag444 = []

with open('100_cycles_5Vgt_4.44Vs_sweep_rate.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        bia444.append(float(row[0]))
        curren444.append(float(row[1]))
        leakag444.append(float(row[2]))

# %%
fig = plt.figure(figsize=(3.5,3.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(bias70,current70, '-', ms = 1, lw = 0.1, color = 'forestgreen', label = 'I$_{ds}$ (A) ')
plt.plot(bias70,leakage70, '-', ms = 5, lw = 0.1, color = 'red', label = 'Gate Leakage')
  
ax2.set_ylim([5e-11,1e-6])
ax2.set_xlim([-20,20])
ax2.set_xlabel('V$_{ds}$ (V)', fontsize = 12)
ax2.set_ylabel(' I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('Cycles #1-#70')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("sweeps_1_to_70.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.5,3.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(bias70,current70, '-', ms = 1, lw = 0.1, color = 'forestgreen', label = 'I$_{ds}$ (A) ')
plt.plot(bias70,leakage70, '-', ms = 5, lw = 0.1, color = 'red', label = 'Gate Leakage')
  
ax2.set_ylim([5e-10,1e-8])
ax2.set_xlim([0,9])
ax2.set_xlabel('V$_{ds}$ (V)', fontsize = 12)
ax2.set_ylabel(' I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('Cycles #1-#70')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("sweeps_1_to_70_loop.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.5,3.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(bias50f,current50f, '-', ms = 1, lw = 0.1, color = 'forestgreen', label = 'I$_{ds}$ (A) ')
plt.plot(bias50f,leakage50f, '-', ms = 5, lw = 0.1, color = 'red', label = 'Gate Leakage')
  
ax2.set_ylim([5e-11,1e-6])
ax2.set_xlim([-20,20])
ax2.set_xlabel('V$_{ds}$ (V)', fontsize = 12)
ax2.set_ylabel(' I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('Cycles #70-#120')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("sweeps_70_to_120.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.5,3.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(bias50f,current50f, '-', ms = 1, lw = 0.1, color = 'forestgreen', label = 'I$_{ds}$ (A) ')
plt.plot(bias50f,leakage50f, '-', ms = 5, lw = 0.1, color = 'red', label = 'Gate Leakage')
  
ax2.set_ylim([5e-10,1e-8])
ax2.set_xlim([0,9])
ax2.set_xlabel('V$_{ds}$ (V)', fontsize = 12)
ax2.set_ylabel(' I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('Cycles #70-#120')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("sweeps_70_to_120_loop.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.5,3.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(bias50s,current50s, '-', ms = 1, lw = 0.1, color = 'forestgreen', label = 'I$_{ds}$ (A) ')
plt.plot(bias50s,leakage50s, '-', ms = 5, lw = 0.1, color = 'red', label = 'Gate Leakage')
  
ax2.set_ylim([5e-11,1e-6])
ax2.set_xlim([-20,20])
ax2.set_xlabel('V$_{ds}$ (V)', fontsize = 12)
ax2.set_ylabel(' I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('Cycles #120-#170')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("sweeps_120_to_170.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.5,3.5))
fig.canvas.draw()

ax2 = fig.add_subplot(111)

ax2.plot(bias50s,current50s, '-', ms = 1, lw = 0.1, color = 'forestgreen' ,label = 'I$_{ds}$ (A) ')
    
ax2.plot(bias50s,leakage50s, '-', ms = 5, lw = 0.1, color = 'red', label = 'Gate Leakage')
  
ax2.set_ylim([5e-10,1e-8])
ax2.set_xlim([0,9])
ax2.set_xlabel('V$_{ds}$ (V)', fontsize = 12)
ax2.set_ylabel(' I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('Cycles #120-#170')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("sweeps_120_to_170_loop.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.5,3.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(bias50t,current50t, '-', ms = 1, lw = 0.1, color = 'forestgreen', label = 'I$_{ds}$ (A) ')
plt.plot(bias50t,leakage50t, '-', ms = 5, lw = 0.1, color = 'red', label = 'Gate Leakage')
  
ax2.set_ylim([5e-11,1e-6])
ax2.set_xlim([-20,20])
ax2.set_xlabel('V$_{ds}$ (V)', fontsize = 12)
ax2.set_ylabel(' I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('Cycles #170-#220')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("sweeps_170_to_220.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.5,3.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(bias50t,current50t, '-', ms = 1, lw = 0.1, color = 'forestgreen', label = 'I$_{ds}$ (A) ')
plt.plot(bias50t,leakage50t, '-', ms = 5, lw = 0.1, color = 'red', label = 'Gate Leakage')
  
ax2.set_ylim([5e-10,1e-8])
ax2.set_xlim([0,9])
ax2.set_xlabel('V$_{ds}$ (V)', fontsize = 12)
ax2.set_ylabel(' I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('Cycles #170-#220')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("sweeps_170_to_220_loop.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.5,3.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(bias50q,current50q, '-', ms = 1, lw = 0.1, color = 'forestgreen', label = 'I$_{ds}$ (A) ')
plt.plot(bias50q,leakage50q, '-', ms = 5, lw = 0.1, color = 'red', label = 'Gate Leakage')
  
ax2.set_ylim([5e-11,1e-6])
ax2.set_xlim([-20,20])
ax2.set_xlabel('V$_{ds}$ (V)', fontsize = 12)
ax2.set_ylabel(' I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('Cycles #220-#270')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("sweeps_220_to_270.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.5,3.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(bias50q,current50q, '-', ms = 1, lw = 0.1, color = 'forestgreen', label = 'I$_{ds}$ (A) ')
plt.plot(bias50q,leakage50q, '-', ms = 5, lw = 0.1, color = 'red', label = 'Gate Leakage')
  
ax2.set_ylim([5e-10,1e-8])
ax2.set_xlim([0,9])
ax2.set_xlabel('V$_{ds}$ (V)', fontsize = 12)
ax2.set_ylabel(' I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('Cycles #220-#270')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("sweeps_220_to_270_loop.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.5,3.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(bias50q,current50q, '-', ms = 1, lw = 0.1, color = 'forestgreen', label = 'I$_{ds}$ (A) ')
plt.plot(bias50s,current50s, '-', ms = 1, lw = 0.1, color = 'forestgreen', label = 'I$_{ds}$ (A) ')
plt.plot(bias50t,current50t, '-', ms = 1, lw = 0.1, color = 'forestgreen', label = 'I$_{ds}$ (A) ')
plt.plot(bias50q,current50q, '-', ms = 1, lw = 0.1, color = 'forestgreen', label = 'I$_{ds}$ (A) ')
  
ax2.set_ylim([5e-11,1e-6])
ax2.set_xlim([-20,20])
ax2.set_xlabel('V$_{ds}$ (V)', fontsize = 12)
ax2.set_ylabel(' I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('Cycles #70-#270')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("sweeps_70_to_270.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.5,3.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(bias50q,current50q, '-', ms = 1, lw = 0.1, color = 'forestgreen', label = 'I$_{ds}$ (A) ')
plt.plot(bias50s,current50s, '-', ms = 1, lw = 0.1, color = 'forestgreen', label = 'I$_{ds}$ (A) ')
plt.plot(bias50t,current50t, '-', ms = 1, lw = 0.1, color = 'forestgreen', label = 'I$_{ds}$ (A) ')
plt.plot(bias50q,current50q, '-', ms = 1, lw = 0.1, color = 'forestgreen', label = 'I$_{ds}$ (A) ')
  
ax2.set_ylim([5e-10,1e-8])
ax2.set_xlim([0,9])
ax2.set_xlabel('V$_{ds}$ (V)', fontsize = 12)
ax2.set_ylabel(' I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('Cycles #70-#270')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("sweeps_70_to_270_loop.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.5,3.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(bias232,current232, '-', ms = 1, lw = 0.1, color = 'forestgreen', label = 'I$_{ds}$ (A) ')
plt.plot(bias232,leakage232, '-', ms = 5, lw = 0.1, color = 'red', label = 'Gate Leakage')
  
ax2.set_ylim([5e-11,1e-6])
ax2.set_xlim([-20,20])
ax2.set_xlabel('V$_{ds}$ (V)', fontsize = 12)
ax2.set_ylabel(' I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('Cycles #270-#370')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("sweeps_270_to_370.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.5,3.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(bias232,current232, '-', ms = 1, lw = 0.1, color = 'forestgreen', label = 'I$_{ds}$ (A) ')
plt.plot(bias232,leakage232, '-', ms = 5, lw = 0.1, color = 'red', label = 'Gate Leakage')
  
ax2.set_ylim([5e-10,1e-8])
ax2.set_xlim([-9,9])
ax2.set_xlabel('V$_{ds}$ (V)', fontsize = 12)
ax2.set_ylabel(' I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('Cycles #270-#370')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("sweeps_270_to_370_loops.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.5,3.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(bias29,current29, '-', ms = 1, lw = 0.1, color = 'forestgreen', label = 'I$_{ds}$ (A) ')
plt.plot(bias29,leakage29, '-', ms = 5, lw = 0.1, color = 'red', label = 'Gate Leakage')
  
ax2.set_ylim([5e-11,1e-6])
ax2.set_xlim([-20,20])
ax2.set_xlabel('V$_{ds}$ (V)', fontsize = 12)
ax2.set_ylabel(' I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('Cycles #370-#470')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("sweeps_370_to_470.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.5,3.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(bias29,current29, '-', ms = 1, lw = 0.1, color = 'forestgreen', label = 'I$_{ds}$ (A) ')
plt.plot(bias29,leakage29, '-', ms = 5, lw = 0.1, color = 'red', label = 'Gate Leakage')
  
ax2.set_ylim([5e-10,1e-8])
ax2.set_xlim([-9,9])
ax2.set_xlabel('V$_{ds}$ (V)', fontsize = 12)
ax2.set_ylabel(' I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('Cycles #370-#470')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("sweeps_370_to_470_loop.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.5,3.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(bias137,current137, '-', ms = 1, lw = 0.1, color = 'forestgreen', label = 'I$_{ds}$ (A) ')
plt.plot(bias137,leakage137, '-', ms = 5, lw = 0.1, color = 'red', label = 'Gate Leakage')
  
ax2.set_ylim([5e-11,1e-6])
ax2.set_xlim([-20,20])
ax2.set_xlabel('V$_{ds}$ (V)', fontsize = 12)
ax2.set_ylabel(' I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('Cycles #470-#482')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("rate_137.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.5,3.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(bias019,current019, '-', ms = 1, lw = 0.1, color = 'forestgreen', label = 'I$_{ds}$ (A) ')
plt.plot(bias019,leakage019, '-', ms = 5, lw = 0.1, color = 'red', label = 'Gate Leakage')
  
ax2.set_ylim([5e-11,1e-6])
ax2.set_xlim([-20,20])
ax2.set_xlabel('V$_{ds}$ (V)', fontsize = 12)
ax2.set_ylabel(' I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('Cycles #482-#490')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("rate_019.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.5,3.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(bia444,curren444, '-', ms = 1, lw = 0.1, color = 'forestgreen', label = 'I$_{ds}$ (A) ')
plt.plot(bia444,leakag444, '-', ms = 5, lw = 0.1, color = 'red', label = 'Gate Leakage')
  
ax2.set_ylim([5e-11,1e-6])
ax2.set_xlim([-20,20])
ax2.set_xlabel('V$_{ds}$ (V)', fontsize = 12)
ax2.set_ylabel(' I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('Cycles #490-#590')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("rate444.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.5,3.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(post_bias,post_current, '-', ms = 1, lw = 1, color = 'forestgreen', label = 'I$_{ds}$ (A) ')
plt.plot(post_bias,post_leakage, '-', ms = 5, lw = 1, color = 'red', label = 'Gate Leakage')
  
ax2.set_ylim([5e-11,1e-6])
ax2.set_xlim([-20,20])
ax2.set_xlabel('V$_{ds}$ (V)', fontsize = 12)
ax2.set_ylabel(' I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('After > 600 cycles')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("post_everything_IV.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.5,3.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(post_bias,post_current, '-', ms = 1, lw = 1, color = 'forestgreen', label = 'I$_{ds}$ (A) ')
plt.plot(post_bias,post_leakage, '-', ms = 5, lw = 1, color = 'red', label = 'Gate Leakage')
  
ax2.set_ylim([1e-9,1e-8])
ax2.set_xlim([2,6])
ax2.set_xlabel('V$_{ds}$ (V)', fontsize = 12)
ax2.set_ylabel(' I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('After > 600 cycles')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("post_everything_IV_loop.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.5,3.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(gt[0:100],crnt[0:100], '-', ms = 1, lw = 2, color = 'mediumblue', label = 'I$_{ds}$ (A) ')
plt.plot(gt[0:100],lk[0:100], '-', ms = 5, lw = 2, color = 'red', label = 'Gate Leakage')
  
ax2.set_ylim([5e-10,1e-6])
ax2.set_xlim([0,40])
ax2.set_xlabel('V$_{g}$ (V)', fontsize = 12)
ax2.set_ylabel(' I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('After > 600 cycles')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("post_everything_gate.png",bbox_inches='tight', dpi = 300)
plt.show()

# %% [markdown]
# # ON/OFF ratios
#
# ______

# %%
s_444 = pd.read_csv("s_444.csv")
s_290 = pd.read_csv("s_290.csv")
s_232 = pd.read_csv("s_232.csv")
s_210 = pd.read_csv("s_210.csv")
s_163 = pd.read_csv("s_163.csv")
s_137 = pd.read_csv("s_137.csv")
s_019 = pd.read_csv("s_019.csv")

# %%
bool019 = []
for voltage in s_019.bias:
    if 6 > voltage > 5:
        bool019.append(True)
    else:
        bool019.append(False)

# %%
bool137 = []
for voltage in s_137.bias:
    if 6 > voltage > 5:
        bool137.append(True)
    else:
        bool137.append(False)

# %%
bool163 = []
for voltage in s_163.bias:
    if 4.5 > voltage > 3.8:
        bool163.append(True)
    else:
        bool163.append(False)

# %%
bool210 = []
for voltage in s_210.bias:
    if 6 > voltage > 5:
        bool210.append(True)
    else:
        bool210.append(False)

# %%
bool232 = []
for voltage in s_232.bias:
    if 6 > voltage > 5:
        bool232.append(True)
    else:
        bool232.append(False)

# %%
bool290 = []
for voltage in s_290.bias:
    if 6 > voltage > 5:
        bool290.append(True)
    else:
        bool290.append(False)

# %%
bool444 = []
for voltage in s_444.bias:
    if 6 > voltage > 4:
        bool444.append(True)
    else:
        bool444.append(False)

# %%
bool019[0:5]
len(bool019)
# Out:
# 640

# %%
bool137[0:5]
len(bool137)
# Out:
# 960

# %%
bool163[0:5]
len(bool163)
# Out:
# 14000

# %%
bool210[0:5]
len(bool210)
# Out:
# 17883

# %%
bool232[0:5]
len(bool232)
# Out:
# 8000

# %%
bool290[0:5]
len(bool290)
# Out:
# 8000

# %%
bool444[0:5]
len(bool444)
# Out:
# 4000

# %%
f_019 = s_019[bool019]
len(f_019)
f_019
# Out:
#         bias          crnt
# 5    5.26316  3.697200e-09
# 34   5.64103  3.681800e-09
# 85   5.26316  3.747100e-09
# 114  5.64103  3.645700e-09
# 165  5.26316  3.725900e-09
# 194  5.64103  3.690500e-09
# 245  5.26316  3.723900e-09
# 274  5.64103  3.787800e-09
# 325  5.26316  3.684300e-09
# 354  5.64103  3.632800e-09
# 405  5.26316  3.601100e-09
# 434  5.64103  3.535800e-09
# 482   4.44300  2.278400e-08
# 497   5.26337  1.445000e-09
# 522   4.44298  2.302900e-08
# 537   5.26391  3.013000e-09
# 562   4.44300  2.281200e-08
# 577   5.26386  2.982000e-09
# ...       ...           ...
# 3402  4.44297  2.285900e-08
# ...

# %%
lrs_019 = f_019[0::2]
hrs_019 = f_019[1::2]

# %%
lrs_137 = f_137[0::2]
hrs_137 = f_137[1::2]

# %%
split = f_163[0::2]
lrs_163 = split[0::2]
hrs_163 = split[1::2]

# %%
lrs_210 = f_210[0::2]
hrs_210 = f_210[1::2]

# %%
lrs_232 = f_232[0::2]
hrs_232 = f_232[1::2]

# %%
lrs_290 = f_290[0::2]
hrs_290 = f_290[1::2]

# %%
lrs_444 = f_444[0::2]
hrs_444 = f_444[1::2]

# %%
lrs_019 = lrs_019['crnt']
hrs_019 = hrs_019['crnt']

# %%
lrs_137 = lrs_137['crnt']
hrs_137 = hrs_137['crnt']

# %%
lrs_163 = lrs_163['crnt']
hrs_163 = hrs_163['crnt']

# %%
lrs_210 = lrs_210['crnt']
hrs_210 = hrs_210['crnt']

# %%
lrs_232 = lrs_232['crnt']
hrs_232 = hrs_232['crnt']

# %%
lrs_290 = lrs_290['crnt']
hrs_290 = hrs_290['crnt']

# %%
lrs_444 = lrs_444['crnt']
hrs_444 = hrs_444['crnt']

# %%
ll_019 = np.asarray(lrs_019)
hh_019 = np.asarray(hrs_019)

# %%
ll_137 = np.asarray(lrs_137)
hh_137 = np.asarray(hrs_137)

# %%
ll_163 = np.asarray(lrs_163)
hh_163 = np.asarray(hrs_163)

# %%
ll_210 = np.asarray(lrs_210)
hh_210 = np.asarray(hrs_210)

# %%
ll_232 = np.asarray(lrs_232)
hh_232 = np.asarray(hrs_232)

# %%
ll_290 = np.asarray(lrs_290)
hh_290 = np.asarray(hrs_290)

# %%
ll_444 = np.asarray(lrs_444)
hh_444 = np.asarray(hrs_444)

# %%
r_019 = ll_019/hh_019
len(r_019)
# Out:
# 8

# %%
r_137 = ll_137/hh_137
len(r_137)
# Out:
# 12

# %%
r_163 = ll_163/hh_163
len(r_163)
# Out:
# 70

# %%
r_210 = ll_210/hh_210
len(r_210)
# Out:
# 226

# %%
r_232 = ll_232/hh_232
len(r_232)
# Out:
# 100

# %%
r_290 = ll_290/hh_290
len(r_290)
# Out:
# 100

# %%
r_444 = ll_444/hh_444
len(r_444)
# Out:
# 100

# %%
lin8 = linspace(0,8,8)
len(lin8)
# Out:
# 8

# %%
lin12 = linspace(0,12,12)
len(lin12)
# Out:
# 12

# %%
lin100 = linspace(0,100,100)
len(lin100)
# Out:
# 100

# %%
lin70 = linspace(0,70,70)
len(lin70)
# Out:
# 70

# %%
lin140 = linspace(0,140,140)
len(lin140)
# Out:
# 140

# %%
lin226 = linspace(0,226,226)
len(lin226)
# Out:
# 226

# %%
lin616 = linspace(0,616,616)
len(lin616)
# Out:
# 616

# %%
fig = plt.figure(figsize=(5,1.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(lin8,ll_019, 'o', ms = 3, lw = 0.1, color = 'white', mew = 1, 
         mec = 'mediumblue',label = 'I$_{ds}$ (A) ')
plt.plot(lin8,hh_019, 'o', ms = 3, lw = 0.1, color = 'white',
         mew = 1, mec = 'red',label = 'I$_{ds}$ (A) ')

  
#ax2.set_ylim([5e-10,1e-8])
#ax2.set_xlim([0,9])
ax2.set_xlabel('Cycle #', fontsize = 12)
ax2.set_ylabel(' I$_{ds}$ (A) ', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('0.19 V/s')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
#ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("currents_0.19.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(5,1.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(lin8,r_019, 'o', ms = 3, lw = 0.1, color = 'white', mew = 1, 
         mec = 'forestgreen',label = 'I$_{ds}$ (A) ')


  
#ax2.set_ylim([5e-10,1e-8])
#ax2.set_xlim([0,9])
ax2.set_xlabel('Cycle #', fontsize = 12)
ax2.set_ylabel(' I$_{LRS}$/I$_{HRS}$ ', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('0.19 V/s')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("ratios_0.19.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(5,1.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(lin12,ll_137, 'o', ms = 3, lw = 0.1, color = 'white', mew = 1, 
         mec = 'mediumblue',label = 'I$_{ds}$ (A) ')
plt.plot(lin12,hh_137, 'o', ms = 3, lw = 0.1, color = 'white',
         mew = 1, mec = 'red',label = 'I$_{ds}$ (A) ')

  
#ax2.set_ylim([5e-10,1e-8])
#ax2.set_xlim([0,9])
ax2.set_xlabel('Cycle #', fontsize = 12)
ax2.set_ylabel(' I$_{ds}$ (A) ', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('1.37 V/s')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
#ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("currents_1.37.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(5,1.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(lin12,r_137, 'o', ms = 3, lw = 0.1, color = 'white', mew = 1, 
         mec = 'forestgreen',label = 'I$_{ds}$ (A) ')


  
#ax2.set_ylim([5e-10,1e-8])
#ax2.set_xlim([0,9])
ax2.set_xlabel('Cycle #', fontsize = 12)
ax2.set_ylabel(' I$_{LRS}$/I$_{HRS}$ ', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('1.37 V/s')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("ratios_1.37.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(5,1.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(lin70,ll_163, 'o', ms = 3, lw = 0.1, color = 'white', mew = 1, 
         mec = 'mediumblue',label = 'I$_{ds}$ (A) ')
plt.plot(lin70,hh_163, 'o', ms = 3, lw = 0.1, color = 'white',
         mew = 1, mec = 'red',label = 'I$_{ds}$ (A) ')

  
#ax2.set_ylim([5e-10,1e-8])
#ax2.set_xlim([0,9])
ax2.set_xlabel('Cycle #', fontsize = 12)
ax2.set_ylabel(' I$_{ds}$ (A) ', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('1.63 V/s')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
#ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("currents_1.63.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(5,1.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(lin70,r_163, 'o', ms = 1, lw = 0.1, color = 'white', mew = 1, 
         mec = 'forestgreen',label = 'I$_{ds}$ (A) ')


  
#ax2.set_ylim([5e-10,1e-8])
#ax2.set_xlim([0,9])
ax2.set_xlabel('Cycle #', fontsize = 12)
ax2.set_ylabel(' I$_{LRS}$/I$_{HRS}$ ', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('1.63 V/s')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("ratios_1.63.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(5,1.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(lin226,ll_210, 'o', ms = 1, lw = 0.1, color = 'white', mew = 1, 
         mec = 'mediumblue',label = 'I$_{ds}$ (A) ')
plt.plot(lin226,hh_210, 'o', ms = 1, lw = 0.1, color = 'white',
         mew = 1, mec = 'red',label = 'I$_{ds}$ (A) ')

  
#ax2.set_ylim([5e-10,1e-8])
#ax2.set_xlim([0,9])
ax2.set_xlabel('Cycle #', fontsize = 12)
ax2.set_ylabel(' I$_{ds}$ (A) ', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('2.1 V/s')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
#ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("currents_2.1.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(5,1.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(lin226,r_210, 'o', ms = 1, lw = 0.1, color = 'white', mew = 1, 
         mec = 'forestgreen',label = 'I$_{ds}$ (A) ')


  
#ax2.set_ylim([5e-10,1e-8])
#ax2.set_xlim([0,9])
ax2.set_xlabel('Cycle #', fontsize = 12)
ax2.set_ylabel(' I$_{LRS}$/I$_{HRS}$ ', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('2.1 V/s')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("ratios_2.1.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(5,1.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(lin100,ll_232, 'o', ms = 1, lw = 0.1, color = 'white', mew = 1, 
         mec = 'mediumblue',label = 'I$_{ds}$ (A) ')
plt.plot(lin100,hh_232, 'o', ms = 1, lw = 0.1, color = 'white',
         mew = 1, mec = 'red',label = 'I$_{ds}$ (A) ')

  
#ax2.set_ylim([5e-10,1e-8])
#ax2.set_xlim([0,9])
ax2.set_xlabel('Cycle #', fontsize = 12)
ax2.set_ylabel(' I$_{ds}$ (A) ', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('2.32 V/s')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
#ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("currents_232_loop.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(5,1.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(lin100,r_232, 'o', ms = 1, lw = 0.1, color = 'white', mew = 1, 
         mec = 'forestgreen',label = 'I$_{ds}$ (A) ')


  
#ax2.set_ylim([5e-10,1e-8])
#ax2.set_xlim([0,9])
ax2.set_xlabel('Cycle #', fontsize = 12)
ax2.set_ylabel(' I$_{LRS}$/I$_{HRS}$ ', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('2.32 V/s')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("ratios_232.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(5,1.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(lin100,ll_290, 'o', ms = 1, lw = 0.1, color = 'white', mew = 1, 
         mec = 'mediumblue',label = 'I$_{ds}$ (A) ')
plt.plot(lin100,hh_290, 'o', ms = 1, lw = 0.1, color = 'white',
         mew = 1, mec = 'red',label = 'I$_{ds}$ (A) ')

  
#ax2.set_ylim([5e-10,1e-8])
#ax2.set_xlim([0,9])
ax2.set_xlabel('Cycle #', fontsize = 12)
ax2.set_ylabel(' I$_{ds}$ (A) ', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('2.90 V/s')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
#ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("currents_290_loop.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(5,1.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(lin100,r_290, 'o', ms = 1, lw = 0.1, color = 'white', mew = 1, 
         mec = 'forestgreen',label = 'I$_{ds}$ (A) ')


  
#ax2.set_ylim([5e-10,1e-8])
#ax2.set_xlim([0,9])
ax2.set_xlabel('Cycle #', fontsize = 12)
ax2.set_ylabel(' I$_{LRS}$/I$_{HRS}$ ', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('2.90 V/s')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("ratios_290.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(5,1.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(lin100,ll_444, 'o', ms = 1, lw = 0.1, color = 'white', mew = 1, 
         mec = 'mediumblue',label = 'I$_{ds}$ (A) ')
plt.plot(lin100,hh_444, 'o', ms = 1, lw = 0.1, color = 'white',
         mew = 1, mec = 'red',label = 'I$_{ds}$ (A) ')

  
ax2.set_ylim([5e-10,5e-8])
#ax2.set_xlim([0,9])
ax2.set_xlabel('Cycle #', fontsize = 12)
ax2.set_ylabel(' I$_{ds}$ (A) ', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('4.44 V/s')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
#ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("currents_444.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(5,1.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(lin100,r_444, 'o', ms = 1, lw = 0.1, color = 'white', mew = 1, 
         mec = 'forestgreen',label = 'I$_{ds}$ (A) ')


  
#ax2.set_ylim([5e-10,1e-8])
#ax2.set_xlim([0,9])
ax2.set_xlabel('Cycle #', fontsize = 12)
ax2.set_ylabel(' I$_{LRS}$/I$_{HRS}$ ', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('4.44 V/s')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("ratios4.44.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
r1 = r_019.tolist()
r2 = r_137.tolist()
r3 = r_163.tolist()
r4 = r_210.tolist()
r5 = r_232.tolist()
r6 = r_290.tolist()
r7 = r_444.tolist()

# %%
e = r1 + r2 + r3 + r4 +r5 +r6 +r7

# %%
len(e)
# Out:
# 616

# %%
l1 = ll_019.tolist()
l2 = ll_137.tolist()
l3 = ll_163.tolist()
l4 = ll_210.tolist()
l5 = ll_232.tolist()
l6 = ll_290.tolist()
l7 = ll_444.tolist()

# %%
h1 = hh_019.tolist()
h2 = hh_137.tolist()
h3 = hh_163.tolist()
h4 = hh_210.tolist()
h5 = hh_232.tolist()
h6 = hh_290.tolist()
h7 = hh_444.tolist()

# %%
l_all = l1 + l2 + l3 + l4 + l5 +l6 +l7

# %%
h_all = h1 + h2 + h3 + h4 + h5 +h6 +h7

# %%
len(h_all)
# Out:
# 616

# %%
fig = plt.figure(figsize=(7.5,5.5))

fig.canvas.draw()

ax1 = fig.add_subplot(211)
plt.plot(lin616,l_all, 'o', ms = 4, lw = 0.1, color = 'white', mew = 1, 
         mec = 'mediumblue',label = 'I$_{ds}$ (A) ')
plt.plot(lin616,h_all, 'o', ms = 4, lw = 0.1, color = 'white',
         mew = 1, mec = 'red',label = 'I$_{ds}$ (A) ')
ax2 = fig.add_subplot(212)
plt.plot(lin616,e, 'o', ms = 4, lw = 0.1, color = 'white', mew = 1, 
         mec = 'black',label = 'I$_{ds}$ (A) ')


ax2.set_xlabel('Cycle #', fontsize = 10)
ax2.set_ylabel(' I$_{LRS}$/I$_{HRS}$ ', fontsize = 12)
ax1.set_ylabel(' I$_{ds}$ (A) ', fontsize = 12)
plt.grid('off')
ax1.set_title('Current endurance over 616 switching cycles @ different frequencies and V$_{g}$ = 5 V\n')

plt.setp(ax1.get_yticklabels(), visible=True, fontsize = 10)
plt.setp(ax2.get_yticklabels(), visible=True, fontsize = 10)
plt.setp(ax1.get_xticklabels(), visible=False, fontsize = 10)
plt.setp(ax2.get_xticklabels(), visible=True, fontsize = 10)

plt.setp(ax1.set_xlim([1,616]))
plt.setp(ax2.set_xlim([1,616]))
ax2.set_yscale('log')
ax1.set_yscale('log')
#plt.setp(ax1.set_ylim([-60,75]))
#plt.setp(ax2.set_ylim([0,40]))
ax1.axvspan(1, 8, color='magenta', alpha=0.325)
ax2.axvspan(1, 8 , color='magenta', alpha=0.325)
ax1.axvspan(8, 20, color='red', alpha=0.325)
ax2.axvspan(8, 20 , color='red', alpha=0.325)
ax1.axvspan(20, 90, color='salmon', alpha=0.325)
ax2.axvspan(20, 90 , color='salmon', alpha=0.325)
ax1.axvspan(90, 316, color='yellow', alpha=0.325)
ax2.axvspan(90, 316 , color='yellow', alpha=0.325)
ax1.axvspan(316, 416, color='forestgreen', alpha=0.325)
ax2.axvspan(316, 416 , color='forestgreen', alpha=0.325)
ax1.axvspan(416, 516, color='mediumblue', alpha=0.325)
ax2.axvspan(416, 516 , color='mediumblue', alpha=0.325)
ax1.axvspan(516, 616, color='dodgerblue', alpha=0.325)
ax2.axvspan(516, 616 , color='dodgerblue', alpha=0.325)
fig.subplots_adjust(hspace=0.1)

#ax1.legend(loc='upper right',ncol = 4, fontsize = 10)
#ax2.legend(loc='upper right',ncol = 4, fontsize = 10)


#major_ticks_1 = np.arange(0, 0.1, 0.02)   
#ax1.set_yticks(major_ticks_1)   
#major_ticks_2 = np.arange(0, 0.14, 0.02)   
#ax2.set_yticks(major_ticks_2)   

plt.savefig("Shared.png",bbox_inches='tight', dpi = 300)

plt.show()

# %%
log_lrs = np.asarray(l_all)
log_hrs = np.asarray(h_all)

# %%
rationale = log_lrs/log_hrs

# %%
logo = np.log(rationale)
len(logo)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-683-df55706940fd> in <module>()
#       1 logo = np.log(rationale)
#       2 len(logo)
# ----> 3 outfile.write("\n".join(logo))
#
# NameError: name 'outfile' is not defined

# %%
fig = plt.figure(figsize=(3.5,3.5))

fig.canvas.draw()

ax1 = fig.add_subplot(111)
#ax1.set_yscale('log')
commutes = pd.Series(logo)
commutes.plot.hist(grid=True, bins=20, rwidth=0.9,
                   color='#607c8e')
plt.setp(ax1.set_xlim([0.5,3.5]))
plt.setp(ax1.set_ylim([0,370]))
plt.title('Resistance ratio across cycles')
plt.xlabel('Log(I$_{LRS}$/I$_{HRS}$)')
plt.ylabel('# of cycles')
plt.grid(axis='y', alpha=0.75)
plt.savefig("histogram.png",bbox_inches='tight', dpi = 300)

plt.show()

# %% [markdown]
# # Set voltages
#
# ______-

# %%
bool232 = []
for I in s_232.crnt:
    if 7.5e-9 > I > 6.82e-9:
        bool232.append(True)
    else:
        bool232.append(False)

# %%
bool232[0:5]
len(bool232)
# Out:
# 8000

# %%
f_232 = s_232[bool232]

len(f_232)
# Out:
# 101

# %%
fig = plt.figure(figsize=(10,5.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(lin100,f_232.bias[0:100], '-h', ms = 7, lw = 0.1, color = 'mediumblue', 
         mfc = 'mediumblue', alpha = 0.7, mew = 1, mec = 'black')


  
ax2.set_ylim([0,5.5])
#ax2.set_xlim([0,9])
ax2.set_xlabel('Cycle #', fontsize = 12)
ax2.set_ylabel(' SET bias (V) ', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('2.32 V/s')
#ax2.set_xscale('log')
#ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
#ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("set_biases_232.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.5,3.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(bias232[0:40],current232[0:40], '-o', ms = 8, lw = 2, color = 'forestgreen', mfc = 'white', mew = 0.5, 
         mec = 'forestgreen')

  
ax2.set_ylim([2e-9,8e-9])
ax2.set_xlim([1,9])
ax2.set_xlabel('V$_{ds}$ (V)', fontsize = 12)
ax2.set_ylabel(' I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('Cycle # 1')
#ax2.set_xscale('log')
#ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("sweeps_232_zoom.png",bbox_inches='tight', dpi = 300)
plt.show()
# Out:
# c:\users\jakub\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
lin66 = linspace(0,66,66)
len(lin66)
# Out:
# 66

# %%
fig = plt.figure(figsize=(3.5,3.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(bias232[4160:4200],current232[4160:4200], '-o', ms = 8, lw = 2, color = 'forestgreen', mfc = 'white', mew = 0.5, 
         mec = 'forestgreen')

  
ax2.set_ylim([2e-9,8e-9])
ax2.set_xlim([1,9])
ax2.set_xlabel('V$_{ds}$ (V)', fontsize = 12)
ax2.set_ylabel(' I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('Cycle # 52')
#ax2.set_xscale('log')
#ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("sweeps_232_zoom_cycle50.png",bbox_inches='tight', dpi = 300)
plt.show()
# Out:
# c:\users\jakub\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
fig = plt.figure(figsize=(3.5,3.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(bias232[6400:6440],current232[6400:6440], '-o', ms = 8, lw = 2, color = 'forestgreen', mfc = 'white', mew = 0.5, 
         mec = 'forestgreen')

  
ax2.set_ylim([2e-9,8e-9])
ax2.set_xlim([1,9])
ax2.set_xlabel('V$_{ds}$ (V)', fontsize = 12)
ax2.set_ylabel(' I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('Cycle # 80')
#ax2.set_xscale('log')
#ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("sweeps_232_zoom_cycle80.png",bbox_inches='tight', dpi = 300)
plt.show()
# Out:
# c:\users\jakub\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
