# %%
import pandas as pd
from matplotlib import rcParams
import matplotlib.pyplot as plt
from matplotlib import gridspec
import numpy as np
import matplotlib as mpl
# %matplotlib inline
import scipy as sp
import csv
import matplotlib.patches as mpatches
import pylab as pb
import matplotlib.ticker as mtick
from matplotlib import cm
from numpy import linspace
from csv import reader
from matplotlib import pyplot
import matplotlib.colors as colors
import bokeh as bk

# %% [markdown]
# # Line profiles of the $E$ mode and $X_B$ excitons in LRS and HRS
# *******

# %%
EProfileLRS=pd.read_csv('EprofilesLRS.csv',sep=',',header=None,index_col=0)
Epper = EProfileLRS[0:485]
EProfileHRS=pd.read_csv('EprofilesHRSfix.csv',sep=',',header=None,index_col=0)
XbProfileLRS=pd.read_csv('XbprofilesLRS.csv',sep=',',header=None,index_col=0)
XbProfileHRS=pd.read_csv('XbprofilesHRS.csv',sep=',',header=None,index_col=0)

# %%
fig = plt.figure(figsize=(4,2))
fig.canvas.draw()
ax1 = fig.add_subplot(111)
ax1.plot(Epper, '-', color = '#1287ba', lw=3, alpha=0.7,
         mfc='gold', dash_capstyle = 'butt', mew = '1.5' ) 
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.yaxis.set_ticks_position('left')
ax1.xaxis.set_ticks_position('bottom')
ax1.set_ylabel('Gray value (a.u.)', fontsize = 10)
ax1.set_xlim([0,2])
ax1.set_ylim([80,135])
#ax1.get_xaxis().set_ticks([])
ax1.get_yaxis().set_ticks([])
plt.show()
fig.savefig('LRS_E_profile.png', dpi=400, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(4,2))
fig.canvas.draw()
ax1 = fig.add_subplot(111)
ax1.plot(EProfileHRS, '-', color = '#1287ba', lw=3, alpha=0.7,
         mfc='gold', dash_capstyle = 'butt', mew = '1.5' ) 
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.yaxis.set_ticks_position('left')
ax1.xaxis.set_ticks_position('bottom')
ax1.set_xlim([0,2])
ax1.set_ylim([80,135])
#ax1.get_xaxis().set_ticks([])
ax1.set_ylabel('Gray value (a.u.)', fontsize = 10)
ax1.get_yaxis().set_ticks([])
plt.show()
fig.savefig('HRS_E_profile.png', dpi=400, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(4,2))
fig.canvas.draw()
ax1 = fig.add_subplot(111)
ax1.plot(XbProfileLRS, '-', color = '#298d47', lw=3, alpha=0.7,
         mfc='gold', dash_capstyle = 'butt', mew = '1.5' ) 
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.yaxis.set_ticks_position('left')
ax1.xaxis.set_ticks_position('bottom')
ax1.set_xlim([0,2])
ax1.set_ylim([90,125])
#ax1.get_xaxis().set_ticks([])
ax1.set_ylabel('Gray value (a.u.)', fontsize = 10)
ax1.get_yaxis().set_ticks([])
plt.show()
fig.savefig('LRS_X_profile.png', dpi=400, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(4,2))
fig.canvas.draw()
ax1 = fig.add_subplot(111)
ax1.plot(XbProfileHRS, '-', color = '#298d47', lw=3, alpha=0.7,
         mfc='gold', dash_capstyle = 'butt', mew = '1.5' ) 
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.yaxis.set_ticks_position('left')
ax1.xaxis.set_ticks_position('bottom')
ax1.set_xlim([0,2])
ax1.set_ylim([90,125])
#ax1.get_xaxis().set_ticks([])
ax1.set_ylabel('Gray value (a.u.)', fontsize = 10)
ax1.get_yaxis().set_ticks([])
plt.show()
fig.savefig('HRS_X_profile.png', dpi=400, bbox_inches='tight')

# %% [markdown]
# # Raman and PL maps
# *******

# %%
EmapLRS=pd.read_csv('Ep.csv',sep=',',header=None,index_col=0)
EmapHRS=pd.read_csv('En.csv',sep=',',header=None,index_col=0)
XbmapLRS=pd.read_csv('Bp.csv',sep=',',header=None,index_col=0)
XbmapHRS=pd.read_csv('Bn.csv',sep=',',header=None,index_col=0)

# %%
fig = plt.figure(figsize=(3,3))
fig.canvas.draw()
ax05 = fig.add_subplot(111)
im = ax05.imshow(EmapLRS,cmap="RdBu",extent=[0, 2, 0, 2],aspect='equal',interpolation='none',)
ax05.set_xlabel('$%s$'%axistitle, fontsize=AxisTitleSize)
ax05.set_ylabel('$%s$'%axistitle, fontsize=AxisTitleSize)
ax05.set_xticks(ticks)
ax05.set_yticks(ticks)

plt.show()
fig.savefig('E_map_LRS.png', dpi=400, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(3,3))
fig.canvas.draw()
ax05 = fig.add_subplot(111)
im = ax05.imshow(EmapHRS,cmap="RdBu",extent=[0, 2, 0, 2],aspect='equal',interpolation='none',)
ax05.set_xlabel('$%s$'%axistitle, fontsize=AxisTitleSize)
ax05.set_ylabel('$%s$'%axistitle, fontsize=AxisTitleSize)
ax05.set_xticks(ticks)
ax05.set_yticks(ticks)

plt.show()
fig.savefig('E_map_HRS.png', dpi=400, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(3,3))
fig.canvas.draw()
ax05 = fig.add_subplot(111)
im = ax05.imshow(XbmapLRS,cmap="PRGn",extent=[0, 2, 0, 2],aspect='equal',interpolation='none',)
ax05.set_xlabel('$%s$'%axistitle, fontsize=AxisTitleSize)
ax05.set_ylabel('$%s$'%axistitle, fontsize=AxisTitleSize)
ax05.set_xticks(ticks)
ax05.set_yticks(ticks)

plt.show()
fig.savefig('X_map_LRS.png', dpi=400, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(3,3))
fig.canvas.draw()
ax05 = fig.add_subplot(111)
im = ax05.imshow(XbmapHRS,cmap="PRGn",extent=[0, 2, 0, 2],aspect='equal',interpolation='none',)
ax05.set_xlabel('$%s$'%axistitle, fontsize=AxisTitleSize)
ax05.set_ylabel('$%s$'%axistitle, fontsize=AxisTitleSize)
ax05.set_xticks(ticks)
ax05.set_yticks(ticks)

plt.show()
fig.savefig('X_map_HRS.png', dpi=400, bbox_inches='tight')

# %% [markdown]
# # Spectra associated with map regions
# ______

# %%
R_LRS1 = []
R_LRS2 = []

with open('Left_LRS.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        R_LRS1.append(float(row[0]))
        R_LRS2.append(float(row[1]))

R_LRS3 = []
R_LRS4 = []

with open('Left_HRS.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        R_LRS3.append(float(row[0]))
        R_LRS4.append(float(row[1]))
        
R_LRS5 = []
R_LRS6 = []

with open('Right_LRS.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        R_LRS5.append(float(row[0]))
        R_LRS6.append(float(row[1]))

R_LRS7 = []
R_LRS8 = []

with open('Right_HRS.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        R_LRS7.append(float(row[0]))
        R_LRS8.append(float(row[1]))
        
PL_LRS1 = []
PL_LRS2 = []

with open('Left_LRS_PL.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        PL_LRS1.append(float(row[0]))
        PL_LRS2.append(float(row[1]))

PL_LRS3 = []
PL_LRS4 = []

with open('Left_HRS_PL.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        PL_LRS3.append(float(row[0]))
        PL_LRS4.append(float(row[1]))
        
PL_LRS5 = []
PL_LRS6 = []

with open('Right_LRS_PL.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        PL_LRS5.append(float(row[0]))
        PL_LRS6.append(float(row[1]))

PL_LRS7 = []
PL_LRS8 = []

with open('Right_HRS_PL.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        PL_LRS7.append(float(row[0]))
        PL_LRS8.append(float(row[1]))

# %%
fig = plt.figure(figsize=(3,3))
fig.canvas.draw()
ax1 = fig.add_subplot(111)
ax1.plot(R_LRS1, R_LRS2, '-', color = '#1287ba', lw=3, alpha=0.7,
         mfc='gold', dash_capstyle = 'butt', mew = '1.5' ) 
ax1.fill(R_LRS1, R_LRS2,  linestyle = 'solid', lw = 2, label='S 2p$_{3/2}$', color= '#1287ba', alpha = 0.5)
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.yaxis.set_ticks_position('left')
ax1.xaxis.set_ticks_position('bottom')
ax1.set_xlim([370,420])
ax1.set_ylim([0.2,5])
ax1.set_ylabel('Intensity (a.u.)', fontsize = 15)
ax1.set_xlabel('Wavenumber (cm$^{-1}$)', fontsize = 15)
#ax1.get_xaxis().set_ticks([])
ax1.get_yaxis().set_ticks([])
plt.show()
fig.savefig('Left_LRS_Raman.png', dpi=400, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(3,3))
fig.canvas.draw()
ax1 = fig.add_subplot(111)
ax1.plot(R_LRS3, R_LRS4, '-', color = '#1287ba', lw=3, alpha=0.7,
         mfc='gold', dash_capstyle = 'butt', mew = '1.5' ) 
ax1.fill(R_LRS3, R_LRS4,  linestyle = 'solid', lw = 2, label='S 2p$_{3/2}$', color= '#1287ba', alpha = 0.5)
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.yaxis.set_ticks_position('left')
ax1.xaxis.set_ticks_position('bottom')
ax1.set_xlim([370,420])
ax1.set_ylim([0.2,5])
#ax1.get_xaxis().set_ticks([])
ax1.set_xlabel('Wavenumber (cm$^{-1}$)', fontsize = 15)
ax1.get_yaxis().set_ticks([])
plt.show()
fig.savefig('Left_HRS_Raman.png', dpi=400, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(3,3))
fig.canvas.draw()
ax1 = fig.add_subplot(111)
ax1.plot(R_LRS5, R_LRS6, '-', color = '#1287ba', lw=3, alpha=0.7,
         mfc='gold', dash_capstyle = 'butt', mew = '1.5' ) 
ax1.fill(R_LRS5, R_LRS6,  linestyle = 'solid', lw = 2, label='S 2p$_{3/2}$', color= '#1287ba', alpha = 0.5)
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.yaxis.set_ticks_position('left')
ax1.xaxis.set_ticks_position('bottom')
ax1.set_xlim([370,420])
ax1.set_ylim([0.2,5])
#ax1.get_xaxis().set_ticks([])
ax1.set_xlabel('Wavenumber (cm$^{-1}$)', fontsize = 15)
ax1.get_yaxis().set_ticks([])
plt.show()
fig.savefig('Right_LRS_Raman.png', dpi=400, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(3,3))
fig.canvas.draw()
ax1 = fig.add_subplot(111)
ax1.plot(R_LRS7, R_LRS8, '-', color = '#1287ba', lw=3, alpha=0.7,
         mfc='gold', dash_capstyle = 'butt', mew = '1.5' ) 
ax1.fill(R_LRS7, R_LRS8,  linestyle = 'solid', lw = 2, label='S 2p$_{3/2}$', color= '#1287ba', alpha = 0.5)
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.yaxis.set_ticks_position('left')
ax1.xaxis.set_ticks_position('bottom')
ax1.set_xlim([370,420])
ax1.set_ylim([0.2,5])
ax1.set_xlabel('Wavenumber (cm$^{-1}$)', fontsize = 15)
#ax1.get_xaxis().set_ticks([])
ax1.get_yaxis().set_ticks([])
plt.show()
fig.savefig('Right_HRS_Raman.png', dpi=400, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(3,3))
fig.canvas.draw()
ax1 = fig.add_subplot(111)
ax1.plot(PL_LRS1, PL_LRS2, '-', color = '#298d47', lw=1, alpha=0.7,
         mfc='gold', dash_capstyle = 'butt', mew = '1.5' ) 
ax1.fill(PL_LRS1, PL_LRS2,  linestyle = 'solid', lw = 2, label='S 2p$_{3/2}$', color= '#298d47', alpha = 0.5)
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.yaxis.set_ticks_position('left')
ax1.xaxis.set_ticks_position('bottom')
ax1.set_xlim([1.8,2.1])
ax1.set_ylim([232,240])
ax1.set_ylabel('Intensity (a.u.)', fontsize = 15)
ax1.set_xlabel('Energy (eV)', fontsize = 15)
ax1.get_xaxis().set_ticks([1.8, 1.9, 2, 2.1])
ax1.get_yaxis().set_ticks([])
plt.show()
fig.savefig('Left_LRS_PL.png', dpi=400, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(3,3))
fig.canvas.draw()
ax1 = fig.add_subplot(111)
ax1.plot(PL_LRS3, PL_LRS4, '-', color = '#298d47', lw=1, alpha=0.7,
         mfc='gold', dash_capstyle = 'butt', mew = '1.5' ) 
ax1.fill(PL_LRS3, PL_LRS4,  linestyle = 'solid', lw = 2, label='S 2p$_{3/2}$', color= '#298d47', alpha = 0.5)
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.yaxis.set_ticks_position('left')
ax1.xaxis.set_ticks_position('bottom')
ax1.set_xlim([1.8,2.1])
ax1.set_ylim([232,240])
ax1.get_xaxis().set_ticks([1.8, 1.9, 2, 2.1])
ax1.get_yaxis().set_ticks([])
ax1.set_xlabel('Energy (eV)', fontsize = 15)
plt.show()
fig.savefig('Left_HRS_PL.png', dpi=400, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(3,3))
fig.canvas.draw()
ax1 = fig.add_subplot(111)
ax1.plot(PL_LRS5, PL_LRS6, '-', color = '#298d47', lw=1, alpha=0.7,
         mfc='gold', dash_capstyle = 'butt', mew = '1.5' ) 
ax1.fill(PL_LRS5, PL_LRS6,  linestyle = 'solid', lw = 2, label='S 2p$_{3/2}$', color= '#298d47', alpha = 0.5)
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.yaxis.set_ticks_position('left')
ax1.xaxis.set_ticks_position('bottom')
ax1.set_xlim([1.8,2.1])
ax1.set_ylim([232,240])
ax1.set_xlabel('Energy (eV)', fontsize = 15)
ax1.get_xaxis().set_ticks([1.8, 1.9, 2, 2.1])
ax1.get_yaxis().set_ticks([])
plt.show()
fig.savefig('Right_LRS_PL.png', dpi=400, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(3,3))
fig.canvas.draw()
ax1 = fig.add_subplot(111)
ax1.plot(PL_LRS7, PL_LRS8, '-', color = '#298d47', lw=1, alpha=0.7,
         mfc='gold', dash_capstyle = 'butt', mew = '1.5' ) 
ax1.fill(PL_LRS7, PL_LRS8,  linestyle = 'solid', lw = 2, label='S 2p$_{3/2}$', color= '#298d47', alpha = 0.5)
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.yaxis.set_ticks_position('left')
ax1.xaxis.set_ticks_position('bottom')
ax1.set_xlim([1.8,2.1])
ax1.set_ylim([232,240])
ax1.set_xlabel('Energy (eV)', fontsize = 15)
ax1.get_xaxis().set_ticks([1.8, 1.9, 2, 2.1])
ax1.get_yaxis().set_ticks([])
plt.show()
fig.savefig('Right_HRS_PL.png', dpi=400, bbox_inches='tight')

# %%
fig  =  plt.figure(figsize=(5,5))
min,  max  =  (-60,60)
step  =  1
mymap  =  mpl.colors.LinearSegmentedColormap.from_list('mycolors',['blue','red'])
Z = [[0,0],[0,0]]
levels = range(min,max+step,step)

CS3 = plt.contourf(Z, levels, cmap='PRGn', fontsize = 40)

plt.clf()  
  
plt.colorbar(CS3) # using the colorbar info I got from contourf 
fig.savefig('redcbar.png', dpi=400, bbox_inches='tight')
