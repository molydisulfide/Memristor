# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy as sp
import csv
import matplotlib.patches as mpatches
import pylab as pb
import matplotlib.ticker as mtick
from matplotlib import cm
from numpy import linspace
from csv import reader
from matplotlib import pyplot
import matplotlib.colors as colors
import bokeh as bk
import pandas as pd

# %%
fig = plt.figure(figsize=(6,6))
fig.canvas.draw()
 
min, max = (2, 280)
step = 10
mymap = mpl.colors.LinearSegmentedColormap.from_list('mycolors',['blue','red'])
Z = [[0,0],[0,0]]
levels = range(min,max+step,step)

CS3 = plt.contourf(Z, levels, cmap='coolwarm', fontsize = 40)

plt.clf()  
cbaxes = fig.add_axes([1, 0.1, 0.03, 0.8]) 
cb = plt.colorbar(CS3, cax = cbaxes) 

opened_file = open("All_gates_0.5V.txt")
csv_data = csv.reader(opened_file, delimiter="\t")
parsed_data = []
for row in csv_data:
    parsed_data.append(row)
opened_file.close()
data = np.array(parsed_data)

opened_file4 = open("All_gates_1V.txt")
csv_data4 = csv.reader(opened_file4, delimiter="\t")
parsed_data4 = []
for row in csv_data4:
    parsed_data4.append(row)
opened_file4.close()
data4 = np.array(parsed_data4)

opened_file6 = open("All_gates_2V.txt")
csv_data6 = csv.reader(opened_file6, delimiter="\t")
parsed_data6 = []
for row in csv_data6:
    parsed_data6.append(row)
opened_file6.close()
data6 = np.array(parsed_data6)

opened_file8 = open("All_gates_5V.txt")
csv_data8 = csv.reader(opened_file8, delimiter="\t")
parsed_data8 = []
for row in csv_data8:
    parsed_data8.append(row)
opened_file8.close()
data8 = np.array(parsed_data8)

ax1 = fig.add_subplot(221)
colormap = plt.get_cmap('coolwarm')
ax1.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 14)])

for i in range(1,14):
        plt.plot(data[0:100,0],data[0:100,i], lw = 2)
        
ax1.set_ylim([1e-10,3e-6])
#ax1.set_xlabel('Gate bias (V)', fontsize = 15)
ax1.set_ylabel('I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
ax1.set_yscale('log')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax1.set_title('V$_{ds}$ = 0.5 V')

ax2 = fig.add_subplot(222)

ax2.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 14)])

for i in range(1,14):
        plt.plot(data4[0:100,0],data4[0:100,i], lw = 2)
        
ax2.set_ylim([1e-10,1e-5])
#ax2.set_xlabel('Gate bias (V)', fontsize = 15)
#ax2.set_ylabel('I$_{DS}$ (A)', fontsize = 15)
plt.ticklabel_format(style='sci', axis='y')
ax2.set_yscale('log')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('V$_{ds}$ = 1 V')

ax3 = fig.add_subplot(223)

ax3.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 14)])

for i in range(1,14):
        plt.plot(data6[0:100,0],data6[0:100,i], lw = 2)
        
ax3.set_ylim([1e-10,1e-5])
ax3.set_xlabel('Gate bias (V)', fontsize = 12)
ax3.set_ylabel('I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
ax3.set_yscale('log')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax3.set_title('V$_{ds}$ = 2 V')

ax4 = fig.add_subplot(224)

ax4.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 14)])

for i in range(1,14):
        plt.plot(data8[0:100,0],data8[0:100,i], lw = 2)
        
ax4.set_ylim([1e-10,5e-5])
ax4.set_xlabel('Gate bias (V)', fontsize = 12)
#ax4.set_ylabel('I$_{DS}$ (A)', fontsize = 15)
plt.ticklabel_format(style='sci', axis='y')
ax4.set_yscale('log')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax4.set_title('V$_{ds}$ = 5 V')

#ax1.set_ylabel('Conductance (S)', fontsize = 12)
#ax3.set_xlabel('Exposure time (s)', fontsize = 12)
#ax3.set_ylabel('Conductance (S)', fontsize = 12)
#ax4.set_xlabel('Exposure time (s)', fontsize = 12)

plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax3.get_xticklabels(), visible=True)
plt.setp(ax2.get_xticklabels(), visible=False)
plt.setp(ax2.get_yticklabels(), visible=True)
plt.setp(ax4.get_yticklabels(), visible=True)
plt.setp(ax4.get_xticklabels(), visible=True)

ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax3.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('left')
ax4.xaxis.set_ticks_position('bottom')
ax4.yaxis.set_ticks_position('left')

major_ticks_1 = np.arange(-60, 61, 60)   
ax4.set_xticks(major_ticks_1) 
ax2.set_xticks(major_ticks_1)
ax3.set_xticks(major_ticks_1) 
ax1.set_xticks(major_ticks_1)

plt.savefig("HRS_all_gates_log.png",bbox_inches='tight', dpi = 300)
plt.show()
# Out:
# c:\users\jakub\anaconda3\lib\site-packages\matplotlib\cbook.py:137: MatplotlibDeprecationWarning: The set_color_cycle attribute was deprecated in version 1.5. Use set_prop_cycle instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
fig = plt.figure(figsize=(2.5,2.5))
fig.canvas.draw()
colormap = plt.get_cmap('coolwarm')

opened_file8 = open("All_gates_5V.txt")
csv_data8 = csv.reader(opened_file8, delimiter="\t")
parsed_data8 = []
for row in csv_data8:
    parsed_data8.append(row)
opened_file8.close()
data8 = np.array(parsed_data8)

ax4 = fig.add_subplot(111)

ax4.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 15)])

for i in range(1,15):
        plt.plot(data8[0:100,0],data8[0:100,i], lw = 2)
        
ax4.set_ylim([1e-10,5e-5])
ax4.set_xlabel('Gate bias (V)', fontsize = 12)
ax4.set_ylabel('I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
ax4.set_yscale('log')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
#ax4.set_title('V$_{ds}$ = 5 V')
plt.setp(ax4.get_yticklabels(), visible=True)
plt.setp(ax4.get_xticklabels(), visible=True)
ax4.spines['right'].set_visible(False)
ax4.spines['top'].set_visible(False)
ax4.xaxis.set_ticks_position('bottom')
ax4.yaxis.set_ticks_position('left')

major_ticks_1 = np.arange(-60, 61, 60)   
ax4.set_xticks(major_ticks_1) 
plt.savefig("HRS_5V_gate_log.png",bbox_inches='tight', dpi = 300)
plt.show()
# Out:
# c:\users\jakub\anaconda3\lib\site-packages\matplotlib\cbook.py:137: MatplotlibDeprecationWarning: The set_color_cycle attribute was deprecated in version 1.5. Use set_prop_cycle instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
fig = plt.figure(figsize=(6,6))
fig.canvas.draw()
 
min, max = (2, 280)
step = 10
mymap = mpl.colors.LinearSegmentedColormap.from_list('mycolors',['blue','red'])
Z = [[0,0],[0,0]]
levels = range(min,max+step,step)

CS3 = plt.contourf(Z, levels, cmap='coolwarm', fontsize = 40)

plt.clf()  
cbaxes = fig.add_axes([1, 0.1, 0.03, 0.8]) 
cb = plt.colorbar(CS3, cax = cbaxes) 

opened_file = open("All_gates_0.5V.txt")
csv_data = csv.reader(opened_file, delimiter="\t")
parsed_data = []
for row in csv_data:
    parsed_data.append(row)
opened_file.close()
data = np.array(parsed_data)

opened_file4 = open("All_gates_1V.txt")
csv_data4 = csv.reader(opened_file4, delimiter="\t")
parsed_data4 = []
for row in csv_data4:
    parsed_data4.append(row)
opened_file4.close()
data4 = np.array(parsed_data4)

opened_file6 = open("All_gates_2V.txt")
csv_data6 = csv.reader(opened_file6, delimiter="\t")
parsed_data6 = []
for row in csv_data6:
    parsed_data6.append(row)
opened_file6.close()
data6 = np.array(parsed_data6)

opened_file8 = open("All_gates_5V.txt")
csv_data8 = csv.reader(opened_file8, delimiter="\t")
parsed_data8 = []
for row in csv_data8:
    parsed_data8.append(row)
opened_file8.close()
data8 = np.array(parsed_data8)

ax1 = fig.add_subplot(221)
colormap = plt.get_cmap('coolwarm')
ax1.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 14)])

for i in range(1,14):
        plt.plot(data[0:100,0],data[0:100,i], lw = 2)
        
ax1.set_ylim([1e-10,1.2e-6])
#ax1.set_xlabel('Gate bias (V)', fontsize = 15)
ax1.set_ylabel('I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax1.set_title('V$_{ds}$ = 0.5 V')

ax2 = fig.add_subplot(222)

ax2.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 14)])

for i in range(1,14):
        plt.plot(data4[0:100,0],data4[0:100,i], lw = 2)
        
ax2.set_ylim([1e-10,3e-6])
#ax2.set_xlabel('Gate bias (V)', fontsize = 15)
#ax2.set_ylabel('I$_{DS}$ (A)', fontsize = 15)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('V$_{ds}$ = 1 V')

ax3 = fig.add_subplot(223)

ax3.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 14)])

for i in range(1,14):
        plt.plot(data6[0:100,0],data6[0:100,i], lw = 2)
        
ax3.set_ylim([1e-10,6.5e-6])
ax3.set_xlabel('Gate bias (V)', fontsize = 12)
ax3.set_ylabel('I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax3.set_title('V$_{ds}$ = 2 V')

ax4 = fig.add_subplot(224)

ax4.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 14)])

for i in range(1,14):
        plt.plot(data8[0:100,0],data8[0:100,i], lw = 2)
        
ax4.set_ylim([1e-10,2.1e-5])
ax4.set_xlabel('Gate bias (V)', fontsize = 12)
#ax4.set_ylabel('I$_{DS}$ (A)', fontsize = 15)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax4.set_title('V$_{ds}$ = 5 V')

#ax1.set_ylabel('Conductance (S)', fontsize = 12)
#ax3.set_xlabel('Exposure time (s)', fontsize = 12)
#ax3.set_ylabel('Conductance (S)', fontsize = 12)
#ax4.set_xlabel('Exposure time (s)', fontsize = 12)

plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax3.get_xticklabels(), visible=True)
plt.setp(ax2.get_xticklabels(), visible=False)
plt.setp(ax2.get_yticklabels(), visible=True)
plt.setp(ax4.get_yticklabels(), visible=True)
plt.setp(ax4.get_xticklabels(), visible=True)

ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax3.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('left')
ax4.xaxis.set_ticks_position('bottom')
ax4.yaxis.set_ticks_position('left')

major_ticks_1 = np.arange(-60, 61, 60)   
ax4.set_xticks(major_ticks_1) 
ax2.set_xticks(major_ticks_1)
ax3.set_xticks(major_ticks_1) 
ax1.set_xticks(major_ticks_1)
ax1.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax2.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax3.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax4.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.savefig("HRS_all_gates_linear.png",bbox_inches='tight', dpi = 300)
plt.show()
# Out:
# c:\users\jakub\anaconda3\lib\site-packages\matplotlib\cbook.py:137: MatplotlibDeprecationWarning: The set_color_cycle attribute was deprecated in version 1.5. Use set_prop_cycle instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
fig = plt.figure(figsize=(6,6))
fig.canvas.draw()
 
min, max = (-60, 60)
step = 1
mymap = mpl.colors.LinearSegmentedColormap.from_list('mycolors',['blue','red'])
Z = [[0,0],[0,0]]
levels = range(min,max+step,step)

CS3 = plt.contourf(Z, levels, cmap='PuOr', fontsize = 40)

plt.clf()  
cbaxes = fig.add_axes([1, 0.1, 0.03, 0.8]) 
cb = plt.colorbar(CS3, cax = cbaxes) 

opened_file = open("Conductances_0.5V.txt")
csv_data = csv.reader(opened_file, delimiter="\t")
parsed_data = []
for row in csv_data:
    parsed_data.append(row)
opened_file.close()
data = np.array(parsed_data)
new_data = data[:,0::2]

opened_file4 = open("Conductances_1V.txt")
csv_data4 = csv.reader(opened_file4, delimiter="\t")
parsed_data4 = []
for row in csv_data4:
    parsed_data4.append(row)
opened_file4.close()
data4 = np.array(parsed_data4)
new_data4 = data4[:,0::2]

opened_file6 = open("Conductances_2V.txt")
csv_data6 = csv.reader(opened_file6, delimiter="\t")
parsed_data6 = []
for row in csv_data6:
    parsed_data6.append(row)
opened_file6.close()
data6 = np.array(parsed_data6)
new_data6 = data6[:,0::2]

opened_file8 = open("Conductances_5V.txt")
csv_data8 = csv.reader(opened_file8, delimiter="\t")
parsed_data8 = []
for row in csv_data8:
    parsed_data8.append(row)
opened_file8.close()
data8 = np.array(parsed_data8)
new_data8 = data8[:,0::2]

ax1 = fig.add_subplot(221)
colormap = plt.get_cmap('PuOr')
ax1.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 50)])

for i in range(1,50):
        plt.plot(new_data[0:14,0],new_data[0:14,i], lw = 2)
        
ax1.set_ylim([1e-10,3e-6])
ax1.set_xlim([0,280])
#ax1.set_xlabel('Gate bias (V)', fontsize = 15)
ax1.set_ylabel('G (S)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax1.set_title('V$_{ds}$ = 0.5 V')

ax2 = fig.add_subplot(222)

ax2.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 50)])

for i in range(1,50):
        plt.plot(new_data4[0:14,0],new_data4[0:14,i], lw = 2)
        
ax2.set_ylim([1e-10,3e-6])
ax2.set_xlim([0,280])
#ax2.set_xlabel('Gate bias (V)', fontsize = 15)
#ax2.set_ylabel('I$_{DS}$ (A)', fontsize = 15)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('V$_{ds}$ = 1 V')

ax3 = fig.add_subplot(223)

ax3.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 50)])

for i in range(1,50):
        plt.plot(new_data6[0:14,0],new_data6[0:14,i], lw = 2)
        
ax3.set_ylim([1e-10,3.5e-6])
ax3.set_xlim([0,280])
ax3.set_xlabel('Temperature (K)', fontsize = 12)
ax3.set_ylabel('G (S)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax3.set_title('V$_{ds}$ = 2 V')

ax4 = fig.add_subplot(224)

ax4.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 50)])

for i in range(1,50):
        plt.plot(new_data8[0:14,0],new_data8[0:14,i], lw = 2)
        
ax4.set_ylim([1e-10,4e-6])
ax4.set_xlim([0,280])
ax4.set_xlabel('Temperature (K)', fontsize = 12)
#ax4.set_ylabel('I$_{DS}$ (A)', fontsize = 15)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax4.set_title('V$_{ds}$ = 5 V')

#ax1.set_ylabel('Conductance (S)', fontsize = 12)
#ax3.set_xlabel('Exposure time (s)', fontsize = 12)
#ax3.set_ylabel('Conductance (S)', fontsize = 12)
#ax4.set_xlabel('Exposure time (s)', fontsize = 12)

plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax3.get_xticklabels(), visible=True)
plt.setp(ax2.get_xticklabels(), visible=False)
plt.setp(ax2.get_yticklabels(), visible=True)
plt.setp(ax4.get_yticklabels(), visible=True)
plt.setp(ax4.get_xticklabels(), visible=True)

ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax3.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('left')
ax4.xaxis.set_ticks_position('bottom')
ax4.yaxis.set_ticks_position('left')

#major_ticks_1 = np.arange(-60, 61, 60)   
#ax4.set_xticks(major_ticks_1) 
#ax2.set_xticks(major_ticks_1)
#ax3.set_xticks(major_ticks_1) 
#ax1.set_xticks(major_ticks_1)
ax1.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax2.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax3.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax4.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.savefig("HRS_all_conductances.png",bbox_inches='tight', dpi = 300)
plt.show()
# Out:
# c:\users\jakub\anaconda3\lib\site-packages\matplotlib\cbook.py:137: MatplotlibDeprecationWarning: The set_color_cycle attribute was deprecated in version 1.5. Use set_prop_cycle instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
fig = plt.figure(figsize=(2.5,2.5))
fig.canvas.draw()
colormap = plt.get_cmap('PuOr')

opened_file8 = open("Conductances_5V.txt")
csv_data8 = csv.reader(opened_file8, delimiter="\t")
parsed_data8 = []
for row in csv_data8:
    parsed_data8.append(row)
opened_file8.close()
data8 = np.array(parsed_data8)
new_data8 = data8[:,0::2]


ax4 = fig.add_subplot(111)

ax4.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 50)])

for i in range(1,50):
        plt.plot(new_data8[0:14,0],new_data8[0:14,i], lw = 1.75)
        
ax4.set_ylim([1e-10,4e-6])
ax4.set_xlim([0,280])
ax4.set_xlabel('Temperature (K)', fontsize = 10)
ax4.set_ylabel('HRS conductance ($\mu$S)', fontsize = 10)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
#ax4.set_title('HRS')


plt.setp(ax4.get_yticklabels(), visible=True)
plt.setp(ax4.get_xticklabels(), visible=True)
ax4.spines['right'].set_visible(False)
ax4.spines['top'].set_visible(False)
ax4.xaxis.set_ticks_position('bottom')
ax4.yaxis.set_ticks_position('left')

ax4.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.savefig("HRS_5V_conductances.png",bbox_inches='tight', dpi = 300)
plt.show()
# Out:
# c:\users\jakub\anaconda3\lib\site-packages\matplotlib\cbook.py:137: MatplotlibDeprecationWarning: The set_color_cycle attribute was deprecated in version 1.5. Use set_prop_cycle instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
fig = plt.figure(figsize=(6,6))
fig.canvas.draw()
 
min, max = (-60, 60)
step = 1
mymap = mpl.colors.LinearSegmentedColormap.from_list('mycolors',['blue','red'])
Z = [[0,0],[0,0]]
levels = range(min,max+step,step)

CS3 = plt.contourf(Z, levels, cmap='PuOr', fontsize = 40)

plt.clf()  
cbaxes = fig.add_axes([1, 0.1, 0.03, 0.8]) 
cb = plt.colorbar(CS3, cax = cbaxes) 

opened_file = open("Conductances_0.5V.txt")
csv_data = csv.reader(opened_file, delimiter="\t")
parsed_data = []
for row in csv_data:
    parsed_data.append(row)
opened_file.close()
data = np.array(parsed_data)
new_data = data[:,0::2]

opened_file4 = open("Conductances_1V.txt")
csv_data4 = csv.reader(opened_file4, delimiter="\t")
parsed_data4 = []
for row in csv_data4:
    parsed_data4.append(row)
opened_file4.close()
data4 = np.array(parsed_data4)
new_data4 = data4[:,0::2]

opened_file6 = open("Conductances_2V.txt")
csv_data6 = csv.reader(opened_file6, delimiter="\t")
parsed_data6 = []
for row in csv_data6:
    parsed_data6.append(row)
opened_file6.close()
data6 = np.array(parsed_data6)
new_data6 = data6[:,0::2]

opened_file8 = open("Conductances_5V.txt")
csv_data8 = csv.reader(opened_file8, delimiter="\t")
parsed_data8 = []
for row in csv_data8:
    parsed_data8.append(row)
opened_file8.close()
data8 = np.array(parsed_data8)
new_data8 = data8[:,0::2]

ax1 = fig.add_subplot(221)
colormap = plt.get_cmap('PuOr')
ax1.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 50)])

for i in range(1,50):
        plt.plot(new_data[0:14,0],new_data[0:14,i], '-o', lw = 1)
        
ax1.set_ylim([1e-10,0.8e-6])
ax1.set_xlim([1,8])
#ax1.set_xlabel('Gate bias (V)', fontsize = 15)
ax1.set_ylabel('G (S)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax1.set_title('V$_{ds}$ = 0.5 V')

ax2 = fig.add_subplot(222)

ax2.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 50)])

for i in range(1,50):
        plt.plot(new_data4[0:14,0],new_data4[0:14,i], '-o', lw = 1)
        
ax2.set_ylim([1e-10,1.5e-6])
ax2.set_xlim([1,8])
#ax2.set_xlabel('Gate bias (V)', fontsize = 15)
#ax2.set_ylabel('I$_{DS}$ (A)', fontsize = 15)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('V$_{ds}$ = 1 V')

ax3 = fig.add_subplot(223)

ax3.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 50)])

for i in range(1,50):
        plt.plot(new_data6[0:14,0],new_data6[0:14,i], '-o', lw = 1)
        
ax3.set_ylim([1e-10,2.5e-6])
ax3.set_xlim([1,8])
ax3.set_xlabel('Temperature (K)', fontsize = 12)
ax3.set_ylabel('G (S)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax3.set_title('V$_{ds}$ = 2 V')

ax4 = fig.add_subplot(224)

ax4.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 50)])

for i in range(1,50):
        plt.plot(new_data8[0:14,0],new_data8[0:14,i], '-o', lw = 1)
        
ax4.set_ylim([1e-10,4e-6])
ax4.set_xlim([1,8])
ax4.set_xlabel('Temperature (K)', fontsize = 12)
#ax4.set_ylabel('I$_{DS}$ (A)', fontsize = 15)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax4.set_title('V$_{ds}$ = 5 V')

#ax1.set_ylabel('Conductance (S)', fontsize = 12)
#ax3.set_xlabel('Exposure time (s)', fontsize = 12)
#ax3.set_ylabel('Conductance (S)', fontsize = 12)
#ax4.set_xlabel('Exposure time (s)', fontsize = 12)

plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax3.get_xticklabels(), visible=True)
plt.setp(ax2.get_xticklabels(), visible=False)
plt.setp(ax2.get_yticklabels(), visible=True)
plt.setp(ax4.get_yticklabels(), visible=True)
plt.setp(ax4.get_xticklabels(), visible=True)

ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax3.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('left')
ax4.xaxis.set_ticks_position('bottom')
ax4.yaxis.set_ticks_position('left')

#major_ticks_1 = np.arange(-60, 61, 60)   
#ax4.set_xticks(major_ticks_1) 
#ax2.set_xticks(major_ticks_1)
#ax3.set_xticks(major_ticks_1) 
#ax1.set_xticks(major_ticks_1)
ax1.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax2.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax3.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax4.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.savefig("HRS_all_conductances_low_T.png",bbox_inches='tight', dpi = 300)
plt.show()
# Out:
# c:\users\jakub\anaconda3\lib\site-packages\matplotlib\cbook.py:137: MatplotlibDeprecationWarning: The set_color_cycle attribute was deprecated in version 1.5. Use set_prop_cycle instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
T = []
mu_5_104 = []
mu_2_104 = []
mu_1_104 = []
mu_05_104 = []

with open('Mobility_at_1.04e-13.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        T.append(float(row[0]))
        mu_5_104.append(float(row[1]))
        mu_2_104.append(float(row[2]))
        mu_1_104.append(float(row[3]))
        mu_05_104.append(float(row[4]))

# %%
T = []
mu_5_365 = []
mu_2_365 = []
mu_1_365 = []
mu_05_365 = []

with open('Mobility_at_3.65e-13.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        T.append(float(row[0]))
        mu_5_365.append(float(row[1]))
        mu_2_365.append(float(row[2]))
        mu_1_365.append(float(row[3]))
        mu_05_365.append(float(row[4]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-7e08edac5cdd> in <module>()
#      12     plots = csv.reader(csvfile, delimiter='\t')
#      13     for row in plots:
# ---> 14         xfitLRS.append(float(row[0]))
#      15         fitLRS.append(float(row[1]))
#      16         xfitHRS.append(float(row[2]))
#
# ValueError: could not convert string to float:

# %%
T = []
mu_5_365 = []
mu_2_365 = []
mu_1_365 = []
mu_05_365 = []

with open('Mobility_at_3.65e-13.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        T.append(float(row[0]))
        mu_5_365.append(float(row[1]))
        mu_2_365.append(float(row[2]))
        mu_1_365.append(float(row[3]))
        mu_05_365.append(float(row[4]))

# %%
fig = plt.figure(figsize=(6.5,3.5))
fig.canvas.draw()
 
ax1 = fig.add_subplot(122)


plt.plot(T,mu_5_365, '-o', lw = 1, color = 'indigo', label = '5 V')
plt.plot(T,mu_2_365, '-o', lw = 1, color = 'red', label = '2 V')
plt.plot(T,mu_1_365, '-o', lw = 1, color = 'orange', label = '1 V')
plt.plot(T,mu_05_365, '-o', lw = 1, color = 'g', label = '0.5 V')
        
#ax1.set_ylim([1,100])
ax1.set_xlim([1,280])
ax1.set_xlabel('Temperature (K)', fontsize = 12)
ax1.set_ylabel('$\mu$ (cm$^{-2}$ V$^{-1}$ s$^{-1}$)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax1.set_title('n$_{2D}$ = 3.65 $\cdot$ 10$^{13}$ cm$^{-2}$')
ax1.set_xscale('log')
#ax1.set_yscale('log')

ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')


ax2 = fig.add_subplot(121)


plt.plot(T,mu_5_104, '-o', lw = 1, color = 'indigo', label = '5 V')
plt.plot(T,mu_2_104, '-o', lw = 1, color = 'red', label = '2 V')
plt.plot(T,mu_1_104, '-o', lw = 1, color = 'orange', label = '1 V')
plt.plot(T,mu_05_104, '-o', lw = 1, color = 'g', label = '0.5 V')
        
#ax1.set_ylim([1,100])
ax2.set_xlim([1,280])
ax2.set_xlabel('Temperature (K)', fontsize = 12)
ax2.set_ylabel('$\mu$ (cm$^{-2}$ V$^{-1}$ s$^{-1}$)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('n$_{2D}$ = 1.04 $\cdot$ 10$^{13}$ cm$^{-2}$')
ax2.set_xscale('log')
#ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)
plt.tight_layout()
plt.savefig("mobo_HRS.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(9,6))
fig.canvas.draw()
 
min, max = (2, 280)
step = 10
mymap = mpl.colors.LinearSegmentedColormap.from_list('mycolors',['blue','red'])
Z = [[0,0],[0,0]]
levels = range(min,max+step,step)

CS3 = plt.contourf(Z, levels, cmap='coolwarm', fontsize = 40)

plt.clf()  
cbaxes = fig.add_axes([1, 0.1, 0.03, 0.8]) 
cb = plt.colorbar(CS3, cax = cbaxes) 

opened_file = open("IVs_-40_gt.txt")
csv_data = csv.reader(opened_file, delimiter="\t")
parsed_data = []
for row in csv_data:
    parsed_data.append(row)
opened_file.close()
data = np.array(parsed_data)

opened_file4 = open("IVs_-20_gt.txt")
csv_data4 = csv.reader(opened_file4, delimiter="\t")
parsed_data4 = []
for row in csv_data4:
    parsed_data4.append(row)
opened_file4.close()
data4 = np.array(parsed_data4)

opened_file6 = open("IVs_0_gt.txt")
csv_data6 = csv.reader(opened_file6, delimiter="\t")
parsed_data6 = []
for row in csv_data6:
    parsed_data6.append(row)
opened_file6.close()
data6 = np.array(parsed_data6)

opened_file8 = open("IVs_20_gt.txt")
csv_data8 = csv.reader(opened_file8, delimiter="\t")
parsed_data8 = []
for row in csv_data8:
    parsed_data8.append(row)
opened_file8.close()
data8 = np.array(parsed_data8)

opened_file9 = open("IVs_40_gt.txt")
csv_data9 = csv.reader(opened_file9, delimiter="\t")
parsed_data9 = []
for row in csv_data9:
    parsed_data9.append(row)
opened_file9.close()
data9 = np.array(parsed_data9)

opened_file7 = open("IVs_60_gt.txt")
csv_data7 = csv.reader(opened_file7, delimiter="\t")
parsed_data7 = []
for row in csv_data7:
    parsed_data7.append(row)
opened_file7.close()
data7 = np.array(parsed_data7)

ax1 = fig.add_subplot(231)
colormap = plt.get_cmap('coolwarm')
ax1.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 14)])

for i in range(1,14):
        plt.plot(data[0:200,0],data[0:200,i], lw = 2)
        
#ax1.set_ylim([1e-10,1.5e-6])
ax1.set_xlabel('V$_{ds}$ (V)', fontsize = 12)
ax1.set_ylabel('I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax1.set_title('V$_{g}$ = -40 V')

ax2 = fig.add_subplot(232)

ax2.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 14)])

for i in range(1,14):
        plt.plot(data4[0:200,0],data4[0:200,i], lw = 2)
        
#ax2.set_ylim([1e-10,3e-6])
ax2.set_xlabel('V$_{ds}$ (V)', fontsize = 12)
ax2.set_ylabel('I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('V$_{g}$ = -20 V')

ax3 = fig.add_subplot(233)

ax3.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 15)])

for i in range(1,15):
        plt.plot(data6[0:200,0],data6[0:200,i], lw = 2)
        
#ax3.set_ylim([1e-10,0.8e-5])
ax3.set_xlabel('V$_{ds}$ (V)', fontsize = 12)
ax3.set_ylabel('I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax3.set_title('V$_{g}$ = 0 V')

ax4 = fig.add_subplot(234)

ax4.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 15)])

for i in range(1,15):
        plt.plot(data8[0:200,0],data8[0:200,i], lw = 2)
        
#ax4.set_ylim([1e-10,3e-5])
ax4.set_xlabel('V$_{ds}$ (V)', fontsize = 12)
ax4.set_ylabel('I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax4.set_title('V$_{g}$ = 20 V')

ax5 = fig.add_subplot(235)

ax5.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 15)])

for i in range(1,15):
        plt.plot(data9[0:200,0],data9[0:200,i], lw = 2)
        
#ax5.set_ylim([1e-10,3e-5])
ax5.set_xlabel('V$_{ds}$  (V)', fontsize = 12)
ax5.set_ylabel('I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax5.set_title('V$_{g}$ = 40 V')

ax6 = fig.add_subplot(236)

ax6.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 15)])

for i in range(1,15):
        plt.plot(data7[0:200,0],data7[0:200,i], lw = 2)
        
#ax6.set_ylim([1e-10,3e-5])
ax6.set_xlabel('V$_{ds}$ (V)', fontsize = 12)
ax6.set_ylabel('I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax6.set_title('V$_{g}$ = 60 V')



ax1.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax2.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax3.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax4.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax5.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax6.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.tight_layout()
plt.savefig("HRS_all_IVs_linear.png",bbox_inches='tight', dpi = 300)
plt.show()
# Out:
# c:\users\jakub\anaconda3\lib\site-packages\matplotlib\cbook.py:137: MatplotlibDeprecationWarning: The set_color_cycle attribute was deprecated in version 1.5. Use set_prop_cycle instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# c:\users\jakub\anaconda3\lib\site-packages\matplotlib\figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
fig = plt.figure(figsize=(2.5,2.5))
fig.canvas.draw()
 

opened_file8 = open("IVs_20_gt.txt")
csv_data8 = csv.reader(opened_file8, delimiter="\t")
parsed_data8 = []
for row in csv_data8:
    parsed_data8.append(row)
opened_file8.close()
data8 = np.array(parsed_data8)

ax4 = fig.add_subplot(111)

ax4.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 15)])

for i in range(1,15):
        plt.plot(data8[0:200,0],data8[0:200,i], lw = 2)
        
#ax4.set_ylim([1e-10,3e-5])
ax4.set_xlabel('V$_{ds}$ (V)', fontsize = 10)
ax4.set_ylabel('I$_{ds}$ ( 10$^{-7}$A)', fontsize = 10)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax4.spines['left'].set_visible(False)
ax4.spines['bottom'].set_visible(False)
ax4.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax4.xaxis.set_ticks_position('top')
ax4.yaxis.set_ticks_position('right')

y1 = [0,-5e-5]
squad = ['0','-5']
ax4.yaxis.set_label_position("left")
ax4.xaxis.set_label_position("top")
ax4.set_yticks(y1)
ax4.set_yticklabels(squad, minor=False)
plt.tight_layout()
plt.savefig("HRS_20gt_IV.png",bbox_inches='tight', dpi = 300)
plt.show()
# Out:
# c:\users\jakub\anaconda3\lib\site-packages\matplotlib\cbook.py:137: MatplotlibDeprecationWarning: The set_color_cycle attribute was deprecated in version 1.5. Use set_prop_cycle instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
fig = plt.figure(figsize=(6,6))
fig.canvas.draw()
 
min, max = (0, 60)
step = 2
mymap = mpl.colors.LinearSegmentedColormap.from_list('mycolors',['blue','red'])
Z = [[0,0],[0,0]]
levels = range(min,max+step,step)

CS3 = plt.contourf(Z, levels, cmap='plasma', fontsize = 40)

plt.clf()  
cbaxes = fig.add_axes([1, 0.1, 0.03, 0.8]) 
cb = plt.colorbar(CS3, cax = cbaxes) 

opened_file = open("VRH_conductances_0.5V.txt")
csv_data = csv.reader(opened_file, delimiter="\t")
parsed_data = []
for row in csv_data:
    parsed_data.append(row)
opened_file.close()
data = np.array(parsed_data)
new_data = data[:,0::3]

opened_file4 = open("VRH_conductances_1V.txt")
csv_data4 = csv.reader(opened_file4, delimiter="\t")
parsed_data4 = []
for row in csv_data4:
    parsed_data4.append(row)
opened_file4.close()
data4 = np.array(parsed_data4)
new_data4 = data4[:,0::3]

opened_file6 = open("VRH_conductances_2V.txt")
csv_data6 = csv.reader(opened_file6, delimiter="\t")
parsed_data6 = []
for row in csv_data6:
    parsed_data6.append(row)
opened_file6.close()
data6 = np.array(parsed_data6)
new_data6 = data6[:,0::3]

opened_file8 = open("VRH_conductances_5V.txt")
csv_data8 = csv.reader(opened_file8, delimiter="\t")
parsed_data8 = []
for row in csv_data8:
    parsed_data8.append(row)
opened_file8.close()
data8 = np.array(parsed_data8)
new_data8 = data8[:,0::3]

ax1 = fig.add_subplot(221)
colormap = plt.get_cmap('plasma')
ax1.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 19)])

for i in range(15,34):
        plt.plot(new_data[0:14,0],new_data[0:14,i], '-o', ms = 4)
        
ax1.set_ylim([5e-9,5e-6])
ax1.set_xlim([0.14,0.33])
#ax1.set_xlabel('Gate bias (V)', fontsize = 15)
ax1.set_ylabel('G (S)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax1.set_yscale('log')
ax1.set_title('V$_{ds}$ = 0.5 V')

ax2 = fig.add_subplot(222)

ax2.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 19)])

for i in range(15,34):
        plt.plot(new_data4[0:14,0],new_data4[0:14,i], '-o', ms = 4)
        
ax2.set_ylim([5e-9,5e-6])
ax2.set_xlim([0.14,0.33])
#ax2.set_xlabel('Gate bias (V)', fontsize = 15)
#ax2.set_ylabel('I$_{DS}$ (A)', fontsize = 15)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_yscale('log')
ax2.set_title('V$_{ds}$ = 1 V')

ax3 = fig.add_subplot(223)

ax3.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 19)])

for i in range(15,34):
        plt.plot(new_data6[0:14,0],new_data6[0:14,i], '-o', ms = 4)
        
ax3.set_ylim([5e-9,5e-6])
ax3.set_xlim([0.14,0.33])

ax3.set_xlabel('T$^{-1/3}$ (K$^{-1/3}$)', fontsize = 12)
ax3.set_ylabel('G (S)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
ax3.set_yscale('log')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax3.set_title('V$_{ds}$ = 2 V')

ax4 = fig.add_subplot(224)

ax4.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 19)])

for i in range(15,34):
        plt.plot(new_data8[0:14,0],new_data8[0:14,i], '-o', ms = 4)
        
ax4.set_ylim([5e-9,6e-6])
ax4.set_xlim([0.14,0.33])

ax4.set_xlabel('T$^{-1/3}$ (K$^{-1/3}$)', fontsize = 12)
#ax4.set_ylabel('I$_{DS}$ (A)', fontsize = 15)
plt.ticklabel_format(style='sci', axis='y')
ax4.set_yscale('log')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax4.set_title('V$_{ds}$ = 5 V')

#ax1.set_ylabel('Conductance (S)', fontsize = 12)
#ax3.set_xlabel('Exposure time (s)', fontsize = 12)
#ax3.set_ylabel('Conductance (S)', fontsize = 12)
#ax4.set_xlabel('Exposure time (s)', fontsize = 12)

plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax3.get_xticklabels(), visible=True)
plt.setp(ax2.get_xticklabels(), visible=False)
plt.setp(ax2.get_yticklabels(), visible=True)
plt.setp(ax4.get_yticklabels(), visible=True)
plt.setp(ax4.get_xticklabels(), visible=True)

ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax3.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('left')
ax4.xaxis.set_ticks_position('bottom')
ax4.yaxis.set_ticks_position('left')

#major_ticks_1 = np.arange(-60, 61, 60)   
#ax4.set_xticks(major_ticks_1) 
#ax2.set_xticks(major_ticks_1)
#ax3.set_xticks(major_ticks_1) 
#ax1.set_xticks(major_ticks_1)
plt.savefig("HRS_VRH_conductances.png",bbox_inches='tight', dpi = 300)
plt.show()
# Out:
# c:\users\jakub\anaconda3\lib\site-packages\matplotlib\cbook.py:137: MatplotlibDeprecationWarning: The set_color_cycle attribute was deprecated in version 1.5. Use set_prop_cycle instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
fig = plt.figure(figsize=(3,3))
fig.canvas.draw()

opened_file6 = open("VRH_conductances_2V.txt")
csv_data6 = csv.reader(opened_file6, delimiter="\t")
parsed_data6 = []
for row in csv_data6:
    parsed_data6.append(row)
opened_file6.close()
data6 = np.array(parsed_data6)
new_data6 = data6[:,0::3]

colormap = plt.get_cmap('plasma')

ax3 = fig.add_subplot(111)

ax3.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 19)])

for i in range(15,34):
        plt.plot(new_data6[0:14,0],new_data6[0:14,i], '-o', ms = 4)
        
ax3.set_ylim([5e-9,5e-6])
ax3.set_xlim([0.14,0.33])

ax3.set_xlabel('T$^{-1/3}$ (K$^{-1/3}$)', fontsize = 12)
ax3.set_ylabel('HRS conductance (S)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
ax3.set_yscale('log')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)

plt.setp(ax3.get_xticklabels(), visible=True)

ax3.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('left')
ax3.spines['right'].set_visible(False)
ax3.spines['top'].set_visible(False)


plt.savefig("HRS_VRH_conductances_2V.png",bbox_inches='tight', dpi = 300)
plt.show()
# Out:
# c:\users\jakub\anaconda3\lib\site-packages\matplotlib\cbook.py:137: MatplotlibDeprecationWarning: The set_color_cycle attribute was deprecated in version 1.5. Use set_prop_cycle instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
