# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy as sp
import csv
import matplotlib.patches as mpatches
import pylab as pb
import matplotlib.ticker as mtick
from matplotlib import cm
from numpy import linspace
from csv import reader
from matplotlib import pyplot
import matplotlib.colors as colors
import bokeh as bk
import pandas as pd

# %%
gate = []
LRS_15 = []
HRS_15 = []
LRS_105 = []
HRS_105 = []
LRS_93 = []
HRS_93 = []
LRS_280 = []
HRS_280 = []


with open('room.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        gate.append(float(row[0]))
        LRS_15.append(float(row[1]))
        HRS_15.append(float(row[2]))
        LRS_105.append(float(row[3]))
        HRS_105.append(float(row[4]))
        LRS_93.append(float(row[5]))
        HRS_93.append(float(row[6]))
        LRS_280.append(float(row[7]))
        HRS_280.append(float(row[8]))

# %%
fig = plt.figure(figsize=(6,6))
fig.canvas.draw()
 
ax2 = fig.add_subplot(221)

ax2.plot(gate,LRS_15, '-', ms = 5,lw = 2, color = 'forestgreen', label = 'LRS')
ax2.plot(gate,HRS_15, '-', ms = 5,lw = 2, color = 'mediumblue', label = 'HRS')

ax2.set_ylim([0,2.5e-5])
ax2.set_xlim([-20,60])
ax2.set_xlabel('Gate bias (V)', fontsize = 12)
ax2.set_ylabel('I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('T = 1.5 K')
#ax2.set_xscale('log')
#ax2.set_yscale('log')
ax2.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

ax1 = fig.add_subplot(222)

ax1.plot(gate,LRS_105, '-', ms = 5,lw = 2, color = 'forestgreen', label = 'LRS')
ax1.plot(gate,HRS_105, '-', ms = 5,lw = 2, color = 'mediumblue', label = 'HRS')

ax1.set_ylim([0,2.5e-5])
ax1.set_xlim([-20,60])
ax1.set_xlabel('Gate bias (V)', fontsize = 12)
ax1.set_ylabel('I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax1.set_title('T = 10.5 K')
ax1.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')

ax3 = fig.add_subplot(223)

ax3.plot(gate,LRS_93, '-', ms = 5,lw = 2, color = 'forestgreen', label = 'LRS')
ax3.plot(gate,HRS_93, '-', ms = 5,lw = 2, color = 'mediumblue', label = 'HRS')

ax3.set_ylim([0,2.5e-5])
ax3.set_xlim([-20,60])
ax3.set_xlabel('Gate bias (V)', fontsize = 12)
ax3.set_ylabel('I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax3.set_title('T = 93 K')
#ax2.set_xscale('log')
#ax2.set_yscale('log')
ax3.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax3.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('left')

ax4 = fig.add_subplot(224)

ax4.plot(gate,LRS_280, '-', ms = 5,lw = 2, color = 'forestgreen', label = 'LRS')
ax4.plot(gate,HRS_280, '-', ms = 5,lw = 2, color = 'mediumblue', label = 'HRS')

ax4.set_ylim([0,2.5e-5])
ax4.set_xlim([-20,60])
ax4.set_xlabel('Gate bias (V)', fontsize = 12)
ax4.set_ylabel('I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax4.set_title('T = 280 K')

ax4.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax4.xaxis.set_ticks_position('bottom')
ax4.yaxis.set_ticks_position('left')

plt.tight_layout()
plt.savefig("gates_multiple_temps.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(6,6))
fig.canvas.draw()
 
ax2 = fig.add_subplot(221)

ax2.plot(gate,LRS_15, '-', ms = 5,lw = 2, color = 'forestgreen', label = 'LRS')
ax2.plot(gate,HRS_15, '-', ms = 5,lw = 2, color = 'mediumblue', label = 'HRS')
ax2.set_yscale('log')
ax2.set_ylim([0,2.5e-5])
ax2.set_xlim([-20,60])
ax2.set_xlabel('Gate bias (V)', fontsize = 12)
ax2.set_ylabel('I$_{ds}$ (A)', fontsize = 12)
#plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('T = 1.5 K')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax1.legend(loc = 'best', fontsize = 8, ncol =2)

ax1 = fig.add_subplot(222)

ax1.plot(gate,LRS_105, '-', ms = 5,lw = 2, color = 'forestgreen', label = 'LRS')
ax1.plot(gate,HRS_105, '-', ms = 5,lw = 2, color = 'mediumblue', label = 'HRS')
ax1.set_yscale('log')
ax1.set_ylim([0,2.5e-5])
ax1.set_xlim([-20,60])
ax1.set_xlabel('Gate bias (V)', fontsize = 12)
ax1.set_ylabel('I$_{ds}$ (A)', fontsize = 12)
#plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax1.set_title('T = 10.5 K')
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')

ax3 = fig.add_subplot(223)

ax3.plot(gate,LRS_93, '-', ms = 5,lw = 2, color = 'forestgreen', label = 'LRS')
ax3.plot(gate,HRS_93, '-', ms = 5,lw = 2, color = 'mediumblue', label = 'HRS')
ax3.set_yscale('log')
ax3.set_ylim([0,2.5e-5])
ax3.set_xlim([-20,60])
ax3.set_xlabel('Gate bias (V)', fontsize = 12)
ax3.set_ylabel('I$_{ds}$ (A)', fontsize = 12)
#plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax3.set_title('T = 93 K')

ax3.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('left')

ax4 = fig.add_subplot(224)

ax4.plot(gate,LRS_280, '-', ms = 5,lw = 2, color = 'forestgreen', label = 'LRS')
ax4.plot(gate,HRS_280, '-', ms = 5,lw = 2, color = 'mediumblue', label = 'HRS')
ax4.set_yscale('log')
ax4.set_ylim([0,2.5e-5])
ax4.set_xlim([-60,60])
ax4.set_xlabel('Gate bias (V)', fontsize = 12)
ax4.set_ylabel('I$_{ds}$ (A)', fontsize = 12)
#plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax4.set_title('T = 280 K')
ax4.xaxis.set_ticks_position('bottom')
ax4.yaxis.set_ticks_position('left')

plt.tight_layout()
plt.savefig("gates_multiple_temps_log.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
gate_200 = []
HRS_200 = []
LRS_200 = []



with open('gates_200K.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        gate_200.append(float(row[0]))
        HRS_200.append(float(row[1]))
        LRS_200.append(float(row[2]))

# %%
fig = plt.figure(figsize=(8,4))
fig.canvas.draw()
 
ax4 = fig.add_subplot(122)

ax4.plot(gate_200,LRS_200, '-', ms = 5,lw = 2, color = 'forestgreen', label = 'LRS')
ax4.plot(gate_200,HRS_200, '-', ms = 5,lw = 2, color = 'mediumblue', label = 'HRS')
ax4.set_yscale('log')
ax4.set_ylim([1e-8,1.5e-5])
ax4.set_xlim([-20,60])
ax4.set_xlabel('Gate bias (V)', fontsize = 12)
ax4.set_ylabel('I$_{ds}$ (A)', fontsize = 12)

plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax4.set_title('T = 200 K')
ax4.xaxis.set_ticks_position('bottom')
ax4.yaxis.set_ticks_position('left')


ax3 = fig.add_subplot(121)

ax3.plot(gate_200,LRS_200, '-', ms = 5,lw = 2, color = 'forestgreen', label = 'LRS')
ax3.plot(gate_200,HRS_200, '-', ms = 5,lw = 2, color = 'mediumblue', label = 'HRS')
#ax4.set_yscale('log')
ax3.set_ylim([0,1.5e-5])
ax3.set_xlim([-20,60])
ax3.set_xlabel('Gate bias (V)', fontsize = 12)
ax3.set_ylabel('I$_{ds}$ (A)', fontsize = 12)
ax3.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax3.set_title('T = 200 K')
ax3.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('left')
ax3.legend(loc = 'best')
plt.tight_layout()
plt.savefig("gates_200K.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
data = pd.read_csv('ratios.csv')
T_r = data['T']
R5 = data['Ratio at 5V']
R2 = data['Ratio at 2V']
R1 = data['Ratio at 1V']
R05 = data['Ratio at 0.5V']

bias = pd.read_csv('bias_ratios.csv')
b = bias['Bias']
b15 = bias['1.5']
b3 = bias['3']
b4 = bias['4']
b6 = bias['6']
b75 = bias['7.5']
b105 = bias['10.5']
b16 = bias['16']
b32 = bias['32']
b64 = bias['64']
b96 = bias['96']
b128 = bias['128']
b160 = bias['160']
b200 = bias['200']
b280 = bias['280']

# %%
fig = plt.figure(figsize=(3.5,3.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(T_r,R5, '-o', ms = 5, lw = 1, color = 'indigo', label = '5 V')
plt.plot(T_r,R2, '-o', ms = 5, lw = 1, color = 'red', label = '2 V')
plt.plot(T_r,R1, '-o', ms = 5, lw = 1, color = 'g', label = '1 V')
plt.plot(T_r,R05, '-o', ms = 5, lw = 1, color = 'orange', label = '0.5 V')

        
#ax1.set_ylim([1,100])
#ax2.set_xlim([1,28])
ax2.set_xlabel('Temperature (K)', fontsize = 12)
ax2.set_ylabel('LRS/HRS @ V$_{g}$ = 0 V', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
#ax2.set_title('n$_{2D}$ = 1.04 $\cdot$ 10$^{13}$ cm$^{-2}$')
ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("gate_ratios_at_0V.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.5,3.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(b,b15, '-o', ms = 5, lw = 1, color = 'indigo', label = '1.5')
plt.plot(b,b3, '-o', ms = 5, lw = 1, color = 'r', label = '3')
plt.plot(b,b4, '-o', ms = 5, lw = 1, color = 'g', label = '4')
plt.plot(b,b6, '-o', ms = 5, lw = 1, color = 'b', label = '6')
plt.plot(b,b75, '-o', ms = 5, lw = 1, color = 'y', label = '7.5')
plt.plot(b,b105, '-o', ms = 5, lw = 1, color = 'orange', label = '10.5')
#plt.plot(b,b16, '-o', ms = 5, lw = 1, color = 'black', label = '16')
#plt.plot(b,b32, '-o', ms = 5, lw = 1, color = 'indigo', label = '32')
#plt.plot(b,b64, '-o', ms = 5, lw = 1, color = 'indigo', label = '64')
#plt.plot(b,b96, '-o', ms = 5, lw = 1, color = 'indigo', label = '96')
#plt.plot(b,b128, '-o', ms = 5, lw = 1, color = 'indigo', label = '128')
#plt.plot(b,b160, '-o', ms = 5, lw = 1, color = 'indigo', label = '160')
#plt.plot(b,b200, '-o', ms = 5, lw = 1, color = 'indigo', label = '200')
#plt.plot(b,b280, '-o', ms = 5, lw = 1, color = 'indigo', label = '280')


        
#ax1.set_ylim([1,100])
ax2.set_xlim([0,6])
ax2.set_xlabel('V$_{ds}$ (V)', fontsize = 12)
ax2.set_ylabel('LRS/HRS', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
#ax2.set_title('n$_{2D}$ = 1.04 $\cdot$ 10$^{13}$ cm$^{-2}$')
#ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("bias_ratios_at_0V.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
T_m = []
LRS_35e13 = []

with open('LRS_mobility_36e13.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        T_m.append(float(row[0]))
        LRS_35e13.append(float(row[1]))
      
    HRS_35e13 = []

with open('HRS_mobility_36e13.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        HRS_35e13.append(float(row[1]))  
HRS_16e13 = []

with open('HRS_mobility_16e13.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        HRS_16e13.append(float(row[1])) 
        
LRS_16e13 = []

with open('LRS_mobility_16e13.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        LRS_16e13.append(float(row[1])) 
        
HRS_17e12 = []

with open('HRS_mobility_17e12.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        HRS_17e12.append(float(row[1])) 
        
LRS_17e12 = []

with open('LRS_mobility_17e12.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        LRS_17e12.append(float(row[1])) 

HRS_0V_gt = []
LRS_0V_gt = []

with open('0V_gate_mobilities_both.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        HRS_0V_gt.append(float(row[1])) 
        LRS_0V_gt.append(float(row[2])) 
HRS_30V_gt = []
LRS_30V_gt = []

with open('30V_gate_mobilities_both.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        HRS_30V_gt.append(float(row[1])) 
        LRS_30V_gt.append(float(row[2]))       
        
HRS_60V_gt = []
LRS_60V_gt = []

with open('60V_gate_mobilities_both.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        HRS_60V_gt.append(float(row[1])) 
        LRS_60V_gt.append(float(row[2]))

# %%
fig = plt.figure(figsize=(8.5,3.2))
fig.canvas.draw()
 
ax1 = fig.add_subplot(133)
plt.plot(T_m,LRS_35e13, '-o',ms = 8,mew = 0.75,  lw = 1, color = 'forestgreen', label = 'LRS')
plt.plot(T_m,HRS_35e13, '-o',ms = 8,mew = 0.75, lw = 1, color = 'gold', label = 'HRS')     
#ax1.set_ylim([1,100])
ax1.set_xlim([1,320])
ax1.set_xlabel('Temperature (K)', fontsize = 12)
ax1.set_ylabel('$\mu$ (cm$^{-2}$ V$^{-1}$ s$^{-1}$)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax1.set_title('n$_{2D}$ = 3.5 $\cdot$ 10$^{13}$ cm$^{-2}$')
ax1.set_xscale('log')
#ax1.set_yscale('log')

ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
ax1.legend(loc = 'best', fontsize = 8, ncol =2)

ax2 = fig.add_subplot(132)
plt.plot(T_m,LRS_16e13, '-o',ms = 8,mew = 0.75,  lw = 1, color = 'forestgreen', label = 'LRS')
plt.plot(T_m,HRS_16e13, '-o',ms = 8,mew = 0.75, lw = 1, color = 'mediumblue', label = 'HRS')      
#ax1.set_ylim([1,100])
ax2.set_xlim([1,320])
ax2.set_xlabel('Temperature (K)', fontsize = 12)
ax2.set_ylabel('$\mu$ (cm$^{-2}$ V$^{-1}$ s$^{-1}$)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('n$_{2D}$ = 1.6 $\cdot$ 10$^{13}$ cm$^{-2}$')
ax2.set_xscale('log')
#ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

ax3 = fig.add_subplot(131)
plt.plot(T_m,LRS_17e12, '-o',ms = 8,mew = 0.75,  lw = 1, color = 'mediumblue', label = 'LRS')
plt.plot(T_m,HRS_17e12, '-o',ms = 8,mew = 0.75, lw = 1, color = 'mediumblue', label = 'HRS')      
#ax1.set_ylim([1,100])
#ax3.set_xlim([60,220])
ax3.set_xlabel('Temperature (K)', fontsize = 12)
ax3.set_ylabel('$\mu$ (cm$^{-2}$ V$^{-1}$ s$^{-1}$)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax3.set_title('n$_{2D}$ = 1.7 $\cdot$ 10$^{12}$ cm$^{-2}$')
ax3.set_xscale('log')
#ax3.set_yscale('log')

ax3.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('left')
ax3.legend(loc = 'best', fontsize = 8, ncol =2)


plt.tight_layout()
plt.savefig("mobilities_5V_same_n2Ds.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
c_LRS = np.asarray(LRS_16e13)
crlrs = c_LRS*10
crlrs

c_HRS = np.asarray(HRS_16e13)
crhrs = c_HRS*10
crhrs
# Out:
# array([ 216.419691  ,  182.5059289 ,  116.312253  ,  111.7520661 ,
#         111.7520661 ,  118.8016529 ,  122.0632411 ,  118.5461732 ,
#         114.6399569 ,  122.8138699 ,  105.7448796 ,   92.92382321,
#          98.39417894,   64.14480776])

# %%
fig = plt.figure(figsize=(2.5,2.5))
fig.canvas.draw()


ax2 = fig.add_subplot(111)
plt.plot(T_m,crlrs, 'o',ms = 9,   alpha=0.85, mfc='forestgreen', dash_capstyle = 'butt', mew = '0.5',
         label = 'LRS')
plt.plot(T_m,crhrs, 'o',ms = 9, alpha=0.85, mfc='mediumblue', dash_capstyle = 'butt', mew = '0.5',
         label = 'HRS')      
ax2.set_ylim([10,300])
ax2.set_xlim([1,450])
ax2.set_xlabel('Temperature (K)', fontsize = 10)
ax2.set_ylabel('$\mu$ (cm$^{-2}$ V$^{-1}$ s$^{-1}$)', fontsize = 10)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
#ax2.set_title('n$_{2D}$ = 1.6 $\cdot$ 10$^{13}$ cm$^{-2}$')
ax2.set_xscale('log')
ax2.set_yscale('log')
ax2.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'lower left', fontsize = 8, ncol =1)

plt.savefig("mobilities_5V_same_n2Ds_30Vgt.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(2.5,2.5))
fig.canvas.draw()


ax2 = fig.add_subplot(111)
plt.plot(T_m,crlrs, 'o',ms = 9,   alpha=0.85, mfc='forestgreen', dash_capstyle = 'butt', mew = '0.5',
         label = 'LRS')
plt.plot(T_m,crhrs, 'o',ms = 9, alpha=0.85, mfc='mediumblue', dash_capstyle = 'butt', mew = '0.5',
         label = 'HRS')      
ax2.set_ylim([10,300])
ax2.set_xlim([1,450])
ax2.set_xlabel('Temperature (K)', fontsize = 10)
ax2.set_ylabel('$\mu$ (cm$^{-2}$ V$^{-1}$ s$^{-1}$)', fontsize = 10)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
#ax2.set_title('n$_{2D}$ = 1.6 $\cdot$ 10$^{13}$ cm$^{-2}$')
ax2.set_xscale('log')
#ax2.set_yscale('log')
ax2.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'lower left', fontsize = 8, ncol =1)

plt.savefig("mobilities_5V_same_n2Ds_30Vgt_linear.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(9,3.2))
fig.canvas.draw()
 
ax1 = fig.add_subplot(131)
plt.plot(T_m,crlrs0, '-o',ms = 8,mew = 0.75,  lw = 1, color = 'forestgreen', label = 'LRS')
plt.plot(T_m,crhrs0, '-o',ms = 8,mew = 0.75, lw = 1, color = 'mediumblue', label = 'HRS')     
#ax1.set_ylim([1,100])
ax1.set_xlim([1,320])
ax1.set_xlabel('Temperature (K)', fontsize = 12)
ax1.set_ylabel('$\mu$ (cm$^{-2}$ V$^{-1}$ s$^{-1}$)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax1.set_title('V$_{g}$ = 0 V')
ax1.set_xscale('log')
#ax1.set_yscale('log')

ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
ax1.legend(loc = 'best', fontsize = 8, ncol =2)

ax2 = fig.add_subplot(132)
plt.plot(T_m,crlrs30, '-o',ms = 8,mew = 0.75,  lw = 1, color = 'forestgreen', label = 'LRS')
plt.plot(T_m,crhrs30, '-o',ms = 8,mew = 0.75, lw = 1, color = 'mediumblue', label = 'HRS')      
#ax1.set_ylim([1,100])
ax2.set_xlim([1,320])
ax2.set_xlabel('Temperature (K)', fontsize = 12)
ax2.set_ylabel('$\mu$ (cm$^{-2}$ V$^{-1}$ s$^{-1}$)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('V$_{g}$ = 30 V')
ax2.set_xscale('log')
#ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

ax3 = fig.add_subplot(133)
plt.plot(T_m,crlrs60, '-o',ms = 8,mew = 0.75,  lw = 1, color = 'forestgreen', label = 'LRS')
plt.plot(T_m,crhrs60, '-o',ms = 8,mew = 0.75, lw = 1, color = 'mediumblue', label = 'HRS')      
#ax1.set_ylim([1,100])
#ax3.set_xlim([60,220])
ax3.set_xlabel('Temperature (K)', fontsize = 12)
ax3.set_ylabel('$\mu$ (cm$^{-2}$ V$^{-1}$ s$^{-1}$)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax3.set_title('V$_{g}$ = 60 V')
ax3.set_xscale('log')
#ax3.set_yscale('log')

ax3.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('left')
ax3.legend(loc = 'best', fontsize = 8, ncol =2)


plt.tight_layout()
plt.savefig("mobilities_5V_different_gates.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
c_LRS30 = np.asarray(LRS_30V_gt)
crlrs30 = c_LRS30*10
crlrs30

c_HRS30 = np.asarray(HRS_30V_gt)
crhrs30 = c_HRS30*10
crhrs30

c_LRS0 = np.asarray(LRS_0V_gt)
crlrs0 = c_LRS0*10
crlrs0

c_HRS0 = np.asarray(HRS_0V_gt)
crhrs0 = c_HRS0*10
crhrs0

c_LRS60 = np.asarray(LRS_60V_gt)
crlrs60 = c_LRS60*10
crlrs60

c_HRS60 = np.asarray(HRS_60V_gt)
crhrs60 = c_HRS60*10
crhrs60
# Out:
# array([ 677.8727991,  649.0118577,  638.3075817,  673.9489759,
#         673.9489759,  694.9694574,  706.8666906,  713.083004 ,
#         696.2163133,  690.3736974,  688.0201222,  685.6988861,
#         700.1976285,  713.3381243])

# %%
LRSnoise30 = pd.read_csv('LRS_noise_30V.csv')
f = LRSnoise30['Frequency']
lrs_n15 = LRSnoise30['1.5']
lrs_n4 = LRSnoise30['4']
lrs_n16 = LRSnoise30['16']
lrs_n32 = LRSnoise30['32']
lrs_n64 = LRSnoise30['64']
lrs_n96 = LRSnoise30['96']
lrs_n128 = LRSnoise30['128']
lrs_n160 = LRSnoise30['160']
lrs_n200 = LRSnoise30['200']
lrs_n280 = LRSnoise30['280']

# %%
HRSnoise30 = pd.read_csv('HRS_noise_30V.csv')
f_h = HRSnoise30['Frequency']
hrs_n15 = HRSnoise30['1.5']
hrs_n4 = HRSnoise30['4']
hrs_n16 = HRSnoise30['16']
hrs_n32 = HRSnoise30['32']
hrs_n64 = HRSnoise30['64']
hrs_n96 = HRSnoise30['96']
hrs_n128 = HRSnoise30['128']
hrs_n160 = HRSnoise30['160']
hrs_n200 = HRSnoise30['200']
hrs_n280 = HRSnoise30['280']

# %%
LRScurrentholds30 = pd.read_csv('LRS_current_holds_30V.csv')
time = LRScurrentholds30['Time']
lrs_h15 = LRScurrentholds30['1.5']
lrs_h4 = LRScurrentholds30['4']
lrs_h16 = LRScurrentholds30['16']
lrs_h32 = LRScurrentholds30['32']
lrs_h64 = LRScurrentholds30['64']
lrs_h96 = LRScurrentholds30['96']
lrs_h128 = LRScurrentholds30['128']
lrs_h160 = LRScurrentholds30['160']
lrs_h200 = LRScurrentholds30['200']
lrs_h280 = LRScurrentholds30['280']

# %%
HRScurrentholds30 = pd.read_csv('HRS_current_holds_30V.csv')
time_h = HRScurrentholds30['Time']
hrs_h15 = HRScurrentholds30['1.5']
hrs_h4 = HRScurrentholds30['4']
hrs_h16 = HRScurrentholds30['16']
hrs_h32 = HRScurrentholds30['32']
hrs_h64 = HRScurrentholds30['64']
hrs_h96 = HRScurrentholds30['96']
hrs_h128 = HRScurrentholds30['128']
hrs_h160 = HRScurrentholds30['160']
hrs_h200 = HRScurrentholds30['200']
hrs_h280 = HRScurrentholds30['280']

# %%
fig = plt.figure(figsize=(7,3))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(f,lrs_n15, '-', ms = 5, lw = 0.5, color = 'indigo', label = '1.5')
plt.plot(f,lrs_n4, '-', ms = 5, lw = 0.5, color = 'r', label = '4')
plt.plot(f,lrs_n16, '-', ms = 5, lw = 0.5, color = 'g', label = '16')
plt.plot(f,lrs_n32, '-', ms = 5, lw = 0.5, color = 'b', label = '32')
plt.plot(f,lrs_n64, '-', ms = 5, lw = 0.5, color = 'orange', label = '64')
plt.plot(f,lrs_n96, '-', ms = 5, lw = 0.5, color = 'black', label = '96')
plt.plot(f,lrs_n128, '-', ms = 5, lw = 0.5, color = 'magenta', label = '128')
plt.plot(f,lrs_n160, '-', ms = 5, lw = 0.5, color = 'dodgerblue', label = '160')
plt.plot(f,lrs_n200, '-', ms = 5, lw = 0.5, color = 'black', label = '200')
plt.plot(f,lrs_n280, '-', ms = 5, lw = 0.5, color = 'yellow', label = '280')

#ax1.set_ylim([1,100])
ax2.set_xlim([1e-3,30])
ax2.set_xlabel('Frequency (Hz)', fontsize = 12)
ax2.set_ylabel('S/I$^{2}$ (Hz$^{-1}$)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('LRS 1/f noise @ V$_{g}$ = 30 V')
ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("lrs_noise_at_30V.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(7,3))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(time,lrs_h15, '-', ms = 5, lw = 0.5, color = 'indigo', label = '1.5')
plt.plot(time,lrs_h4, '-', ms = 5, lw = 0.5, color = 'r', label = '4')
plt.plot(time,lrs_h16, '-', ms = 5, lw = 0.5, color = 'g', label = '16')
plt.plot(time,lrs_h32, '-', ms = 5, lw = 0.5, color = 'b', label = '32')
plt.plot(time,lrs_h64, '-', ms = 5, lw = 0.5, color = 'orange', label = '64')
plt.plot(time,lrs_h96, '-', ms = 5, lw = 0.5, color = 'black', label = '96')
plt.plot(time,lrs_h128, '-', ms = 5, lw = 0.5, color = 'magenta', label = '128')
plt.plot(time,lrs_h160, '-', ms = 5, lw = 0.5, color = 'dodgerblue', label = '160')
plt.plot(time,lrs_h200, '-', ms = 5, lw = 0.5, color = 'black', label = '200')
plt.plot(time,lrs_h280, '-', ms = 5, lw = 0.5, color = 'yellow', label = '280')

ax2.set_ylim([2e-7,2e-6])
ax2.set_xlim([10,100])
ax2.set_xlabel('Time (s)', fontsize = 12)
ax2.set_ylabel('I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('LRS current holds @ V$_{g}$ = 30 V, V$_{ds}$ = 1 V' )
ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =5)

plt.savefig("lrs_current_holds_at_30V.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(2.5,5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(time,lrs_h15, '-', ms = 5, lw = 0.5, color = 'forestgreen', label = 'LRS')
plt.plot(time,np.abs(hrs_h15), '-', ms = 5, lw = 0.5, color = 'mediumblue', label = 'HRS')
ax2.set_ylim([5e-9,10e-7])
ax2.set_xlim([10,80])
ax2.set_xlabel('Time (s)', fontsize = 12)
ax2.set_ylabel('|I$_{ds}$| (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
x1 = [10,30,50,70]
squad = ['0','20','40','60']

ax2.set_xticks(x1)
ax2.set_xticklabels(squad, minor=False)

ax2.set_yscale('log')
ax2.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
#ax2.legend(loc = 'best', fontsize = 8, ncol =1)

plt.savefig("1overeffs.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(4,1.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

#plt.plot(time,lrs_h15, '-', ms = 5, lw = 1, color = 'forestgreen', label = 'LRS')
plt.plot(time,np.abs(hrs_h15), '-', ms = 5, lw = 1, color = 'mediumblue', label = 'HRS')
ax2.set_ylim([7e-9,1.5e-8])
ax2.set_xlim([30,50])
#ax2.set_xlabel('Time (s)', fontsize = 12)
#ax2.set_ylabel('I$_{ds}$ (A)', fontsize = 12)
#plt.ticklabel_format(style='sci', axis='y')
plt.xticks([])
plt.yticks([])
#ax2.set_title('LRS current holds @ V$_{g}$ = 30 V, V$_{ds}$ = 1 V' )
#ax2.set_xscale('log')
#ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
#ax2.legend(loc = 'best', fontsize = 8, ncol =5)

plt.savefig("hrsnoise.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(4,1.5))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(time,lrs_h15, '-', ms = 5, lw = 1, color = 'forestgreen', label = 'LRS')
#plt.plot(time,np.abs(hrs_h15), '-', ms = 5, lw = 1, color = 'indigo', label = 'HRS')
ax2.set_ylim([4.8e-7,5.25e-7])
ax2.set_xlim([30,50])
#ax2.set_xlabel('Time (s)', fontsize = 12)
#ax2.set_ylabel('I$_{ds}$ (A)', fontsize = 12)
#plt.ticklabel_format(style='sci', axis='y')
plt.xticks([])
plt.yticks([])
#ax2.set_title('LRS current holds @ V$_{g}$ = 30 V, V$_{ds}$ = 1 V' )
#ax2.set_xscale('log')
#ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
#ax2.legend(loc = 'best', fontsize = 8, ncol =5)


plt.savefig("lrsnoise.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(7,3))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(f_h,hrs_n15, '-', ms = 5, lw = 0.5, color = 'indigo', label = '1.5')
plt.plot(f_h,hrs_n4, '-', ms = 5, lw = 0.5, color = 'r', label = '4')
plt.plot(f_h,hrs_n16, '-', ms = 5, lw = 0.5, color = 'g', label = '16')
plt.plot(f_h,hrs_n32, '-', ms = 5, lw = 0.5, color = 'b', label = '32')
plt.plot(f_h,hrs_n64, '-', ms = 5, lw = 0.5, color = 'orange', label = '64')
plt.plot(f_h,hrs_n96, '-', ms = 5, lw = 0.5, color = 'black', label = '96')
plt.plot(f_h,hrs_n128, '-', ms = 5, lw = 0.5, color = 'magenta', label = '128')
plt.plot(f_h,hrs_n160, '-', ms = 5, lw = 0.5, color = 'dodgerblue', label = '160')
plt.plot(f_h,hrs_n200, '-', ms = 5, lw = 0.5, color = 'black', label = '200')
plt.plot(f_h,hrs_n280, '-', ms = 5, lw = 0.5, color = 'yellow', label = '280')

#ax1.set_ylim([1,100])
ax2.set_xlim([1e-3,30])
ax2.set_xlabel('Frequency (Hz)', fontsize = 12)
ax2.set_ylabel('S/I$^{2}$ (Hz$^{-1}$)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('HRS 1/f noise @ V$_{g}$ = 30 V')
ax2.set_xscale('log')
ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("hrs_noise_at_30V.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(7,3))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)

plt.plot(time_h,hrs_h15, '-', ms = 5, lw = 0.5, color = 'indigo', label = '1.5')
plt.plot(time_h,hrs_h4, '-', ms = 5, lw = 0.5, color = 'r', label = '4')
plt.plot(time_h,hrs_h16, '-', ms = 5, lw = 0.5, color = 'g', label = '16')
plt.plot(time_h,hrs_h32, '-', ms = 5, lw = 0.5, color = 'b', label = '32')
plt.plot(time_h,hrs_h64, '-', ms = 5, lw = 0.5, color = 'orange', label = '64')
plt.plot(time_h,hrs_h96, '-', ms = 5, lw = 0.5, color = 'black', label = '96')
plt.plot(time_h,hrs_h128, '-', ms = 5, lw = 0.5, color = 'magenta', label = '128')
plt.plot(time_h,hrs_h160, '-', ms = 5, lw = 0.5, color = 'dodgerblue', label = '160')
plt.plot(time_h,hrs_h200, '-', ms = 5, lw = 0.5, color = 'black', label = '200')
plt.plot(time_h,hrs_h280, '-', ms = 5, lw = 0.5, color = 'yellow', label = '280')

ax2.set_ylim([-1e-8,-2e-6])
ax2.set_xlim([10,100])
ax2.set_xlabel('Time (s)', fontsize = 12)
ax2.set_ylabel('I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('HRS current holds @ V$_{g}$ = 30 V, V$_{ds}$ = -1 V' )
ax2.set_xscale('log')
#ax2.set_yscale('log')

ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.legend(loc = 'best', fontsize = 8, ncol =5)

plt.savefig("hrs_current_holds_at_30V.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
A_inverse_HRS = [3.71535E6,
1.02329E6,
1.12202E6,
7.4131E6,
1.04713E6,
1.7378E6,
7.76247E6,
2.5704E7,
6.76083E7,
8.12831E7]
A_inverse_LRS = [758577575,
117489755.5,
112201845.4,
26915348.04,
251188643.2,
46773514.13,
35481338.92,
53703179.64,
107151930.5,
125892541.2]
T_a = [1.5,
4,
16,
32,
64,
96,
128,
160,
200,
280]
beta_LRS = [1.08,
0.96,
0.72,
1.43,
1.08,
1.17,
0.77,
0.95,
0.93,
1.25]
beta_HRS = [1.02,
1.67,
1.54,
1.14,
1.51,
1.35,
1,
0.84,
1.03,
1.37]

# %%
A_LRS = np.asarray(A_inverse_LRS)
A_HRS = np.asarray(A_inverse_HRS)
A_ratio = A_LRS/A_HRS

# %%
fig = plt.figure(figsize=(3.5,3.5))
fig.canvas.draw()
 
ax1 = fig.add_subplot(111)
plt.plot(T_a,A_inverse_HRS, ':o',ms = 10,mew = 1,  lw = 1, color = 'forestgreen', label = 'LRS')
plt.plot(T_a,A_inverse_LRS, ':o',ms = 10,mew = 1,  lw = 1, color = 'mediumblue', label = 'HRS')
ax1.set_ylim([1e5,1e9])
ax1.set_xlim([1,320])
ax1.set_xlabel('Temperature (K)', fontsize = 12)
ax1.set_ylabel('A', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax1.set_title('V$_{g}$ = 30 V')
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
ax1.legend(loc = 'best', fontsize = 8, ncol =2)

plt.savefig("inverse_A_temp.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.5,3.5))
fig.canvas.draw()
 
ax1 = fig.add_subplot(111)
plt.plot(T_a,beta_HRS, '-o',ms = 8,mew = 0.75,  lw = 1, color = 'magenta', label = 'HRS')
plt.plot(T_a,beta_LRS, '-o',ms = 8,mew = 0.75,  lw = 1, color = 'dodgerblue', label = 'LRS')
#ax1.set_ylim([1e5,1e9])
ax1.set_xlim([1,320])
ax1.set_xlabel('Temperature (K)', fontsize = 12)
ax1.set_ylabel('$\{beta}$', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
#ax1.set_title('V$_{g}$ = 0 V')
ax1.set_xscale('log')
#ax1.set_yscale('log')
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
ax1.legend(loc = 'best', fontsize = 8, ncol =2)

plt.tight_layout()
plt.savefig("betas_temp.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
A_ratio
# Out:
# array([ 204.17392036,  114.8156979 ,   99.99986221,    3.63078173,
#         239.88295933,   26.91536088,    4.57088258,    2.0892927 ,
#           1.58489313,    1.5488157 ])

# %%
fig = plt.figure(figsize=(3.5,3.5))
fig.canvas.draw()
 
ax1 = fig.add_subplot(111)
plt.plot(T_a,A_ratio, 'o',ms = 10,mew = 0.75,  lw = 1, color = 'tomato', label = 'V$_g$ = 30 V')

#ax1.set_ylim([1e5,1e9])
ax1.set_xlim([1,320])
ax1.set_xlabel('Temperature (K)', fontsize = 12)
ax1.set_ylabel('A$_{HRS}$/A$_{LRS}$', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
#ax1.set_title('V$_{g}$ = 0 V')
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
ax1.legend(loc = 'lower left', fontsize = 10, ncol =2)

plt.tight_layout()
plt.savefig("A_ratio.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
V_fb = []
SBH_LRS = []

with open('SBH_LRS.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        V_fb.append(float(row[0]))
        SBH_LRS.append(float(row[1]))
        
V_fb_HRS = []
SBH_HRS = []

with open('SBH_HRS.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        V_fb_HRS.append(float(row[0]))
        SBH_HRS.append(float(row[1]))
V_fb_fit_LRS = []
SBH_LRS_fit = []

with open('LRS_SBH_fit.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        V_fb_fit_LRS.append(float(row[0]))
        SBH_LRS_fit.append(float(row[1]))
        
V_fb_fit_HRS = []
SBH_HRS_fit = []

with open('HRS_SBH_fit.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        V_fb_fit_HRS.append(float(row[0]))
        SBH_HRS_fit.append(float(row[1]))

# %%
fig = plt.figure(figsize=(3.5,3.5))

fig.canvas.draw()

ax2 = fig.add_subplot(111)
plt.plot(V_fb,SBH_LRS, 's',ms = 6,mew = 0.75,  lw = 1, color = 'mediumblue', label = 'LRS')
plt.plot(V_fb_HRS,SBH_HRS, 's',ms = 6,mew = 0.75,  lw = 1, color = 'magenta', label = 'HRS')
plt.plot(V_fb_fit_LRS,SBH_LRS_fit, '-',ms = 6,mew = 0.75,  lw = 2, color = 'mediumblue' )
plt.plot(V_fb_fit_HRS,SBH_HRS_fit, '-',ms = 6,mew = 0.75,  lw = 2, color = 'magenta')
ax2.set_title('V$_{ds}$ = 0.5 V')
ax2.set_xlabel('Gate bias (V)', fontsize = 10)
ax2.set_ylabel('Effective SBH (eV)', fontsize = 10)

plt.setp(ax2.set_xlim([-25,40]))
plt.setp(ax2.set_ylim([-0.01,0.07]))
ax2.legend(loc = 'upper right', fontsize = 9)
#ax2.axhspan(0.0195, 0.0205, color='dodgerblue', alpha=0.5)
#ax2.axhspan(0.02995, 0.03005, color='magenta', alpha=0.5)


plt.savefig("shared_SBHs.png",bbox_inches='tight', dpi = 300)


plt.show()

# %%
V_fb_LRS_1V = []
SBH_LRS_1V = []
V_fb_HRS_1V = []
SBH_HRS_1V = []


with open('SBHs_1V.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        V_fb_LRS_1V.append(float(row[0]))
        SBH_LRS_1V.append(float(row[1]))
        V_fb_HRS_1V.append(float(row[2]))
        SBH_HRS_1V.append(float(row[3]))

# %%
fig = plt.figure(figsize=(4.5,3.5))

fig.canvas.draw()

ax1 = fig.add_subplot(212)
ax1.plot(V_fb_LRS_1V,SBH_LRS_1V, 'o', ms=7,  alpha=0.78, mfc='forestgreen', dash_capstyle = 'butt',
         mew = '0.5', label = 'LRS' ) 
ax2 = fig.add_subplot(211)
ax2.plot(V_fb_HRS_1V,SBH_HRS_1V, 'o', ms=7,  alpha=0.78, mfc='mediumblue', 
         mew = '0.5', label = 'HRS' )

ax1.set_xlabel('Gate bias (V)', fontsize = 12)
ax2.set_ylabel('$\Phi_{b}$ (eV)', fontsize = 13)
ax1.set_ylabel('$\Phi_{b}$ (eV)', fontsize = 13)
plt.grid('off')

plt.setp(ax1.get_yticklabels(), visible=True, fontsize = 10)
plt.setp(ax2.get_yticklabels(), visible=True, fontsize = 10)
plt.setp(ax2.get_xticklabels(), visible=False, fontsize = 10)
plt.setp(ax1.get_xticklabels(), visible=True, fontsize = 10)

plt.setp(ax1.set_xlim([-40,40]))
plt.setp(ax2.set_xlim([-40,40]))
#plt.setp(ax1.set_ylim([-60,75]))
#plt.setp(ax2.set_ylim([0,40]))
ax1.axvspan(-40, -20, color='forestgreen', alpha=0.5)
ax2.axvspan(-40, -7 , color='dodgerblue', alpha=0.5)

fig.subplots_adjust(hspace=0.05)

ax1.legend(loc='upper right',ncol = 4, fontsize = 10)
ax2.legend(loc='upper right',ncol = 4, fontsize = 10)
ax2.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')

major_ticks_1 = np.arange(0, 0.1, 0.02)   
ax1.set_yticks(major_ticks_1)   
major_ticks_2 = np.arange(0, 0.14, 0.03)   
ax2.set_yticks(major_ticks_2)   

plt.savefig("SBHs_Vds_1V.png",bbox_inches='tight', dpi = 300)

plt.show()

# %%
zetas = pd.read_csv('zetas.csv')
gate_z = zetas['vg']
LRS_z = zetas['LRS zeta']
HRS_z = zetas['HRS zeta']

t_0 = pd.read_csv('t_0.csv')
gate_t = t_0['vg']
LRS_t = t_0['LRS T_0']
HRS_t = t_0['HRS T_0']

# %%
fig = plt.figure(figsize=(3.5,3.5))

fig.canvas.draw()

ax2 = fig.add_subplot(111)
plt.plot(gate_z,LRS_z, 'o',ms = 10,mew = 0.85, alpha = 0.75, lw = 1.5, color = 'forestgreen' , label = 'LRS')
plt.plot(gate_z,HRS_z, 'o',ms = 10,mew = 0.85, alpha = 0.75, lw = 1.5, color = 'mediumblue', label = 'HRS')
ax2.fill_between(gate_z, LRS_z, HRS_z, where=LRS_z >= HRS_z, facecolor='dodgerblue', alpha = 0.5,interpolate=True)
ax2.set_ylabel('$\zeta$ (nm)', fontsize = 12)
ax2.set_xlabel('Gate bias (V)', fontsize = 12)

#plt.setp(ax2.set_xlim([-25,40]))
#plt.setp(ax2.set_ylim([-0.01,0.07]))
ax2.legend(loc = 'upper left', fontsize = 9)
ax2.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')

plt.savefig("zetas.png",bbox_inches='tight', dpi = 300)


plt.show()

# %%
fig = plt.figure(figsize=(3.5,3.5))

fig.canvas.draw()

ax2 = fig.add_subplot(111)
plt.plot(gate_t,LRS_t, 'o',ms = 6,mew = 0.75,  lw = 2, color = 'mediumblue' , label = 'LRS')
plt.plot(gate_t,HRS_t, 'o',ms = 6,mew = 0.75,  lw = 2, color = 'magenta', label = 'HRS')
ax2.set_title('V$_{ds}$ = 1 V')
ax2.set_ylabel('$T_{0}$ (K)', fontsize = 10)
ax2.set_xlabel('Gate bias (V)', fontsize = 10)
ax2.set_yscale('log')
#plt.setp(ax2.set_xlim([-25,40]))
#plt.setp(ax2.set_ylim([-0.01,0.07]))
ax2.legend(loc = 'upper right', fontsize = 9)
#ax2.axhspan(0.0195, 0.0205, color='dodgerblue', alpha=0.5)
#ax2.axhspan(0.02995, 0.03005, color='magenta', alpha=0.5)


plt.savefig("T_0.png",bbox_inches='tight', dpi = 300)


plt.show()

# %%
v_d = []
i_d = []



with open('after.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        v_d.append(float(row[0]))
        i_d.append(float(row[1]))

# %%
fig = plt.figure(figsize=(3.5,3.5))
fig.canvas.draw()
 
ax1 = fig.add_subplot(111)
plt.plot(v_d,i_d, '-',ms = 8,mew = 0.75,  lw = 1, color = 'tomato', label = 'After everything')

#ax1.set_ylim([1e5,1e9])
#ax1.set_xlim([1,320])
ax1.set_xlabel('V$_{ds}$ (V)', fontsize = 12)
ax1.set_ylabel('I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax1.set_title('V$_{g}$ = -30 V')
ax1.set_yscale('log')
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
ax1.legend(loc = 'best', fontsize = 8, ncol =2)

plt.tight_layout()
plt.savefig("after_linear.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.5,3.5))
fig.canvas.draw()
 
ax1 = fig.add_subplot(111)
plt.plot(v_d,i_d, '-',ms = 8,mew = 0.75,  lw = 1, color = 'tomato', label = 'After everything')

ax1.set_xlim([0,20])
ax1.set_ylim([1e-10,1.5e-8])
ax1.set_xlabel('V$_{ds}$ (V)', fontsize = 12)
ax1.set_ylabel('I$_{ds}$ (A)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax1.set_title('V$_{g}$ = -30 V')
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
ax1.legend(loc = 'best', fontsize = 8, ncol =2)

plt.tight_layout()
plt.savefig("after_log.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(6,3))
fig.canvas.draw()
 
colormap = plt.get_cmap('RdBu_r')

opened_file = open("HRS_60V_gt_field.txt")
csv_data = csv.reader(opened_file, delimiter="\t")
parsed_data = []
for row in csv_data:
    parsed_data.append(row)
opened_file.close()
data = np.array(parsed_data)

opened_file4 = open("HRS_0V_gt_field.txt")
csv_data4 = csv.reader(opened_file4, delimiter="\t")
parsed_data4 = []
for row in csv_data4:
    parsed_data4.append(row)
opened_file4.close()
data4 = np.array(parsed_data4)
new_data4 = data4[:,0::2]

opened_file8 = open("LRS_60V_gt_field.txt")
csv_data8 = csv.reader(opened_file8, delimiter="\t")
parsed_data8 = []
for row in csv_data8:
    parsed_data8.append(row)
opened_file8.close()
data8 = np.array(parsed_data8)
new_data8 = data8[:,0::2]


ax2 = fig.add_subplot(121)

ax2.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 7)])

for i in range(1,7):
        plt.plot(new_data4[0:100,0],new_data4[0:100,i], lw = 2.5)
        
ax2.set_ylim([0,6.5])
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_xlabel('Electric field (V/$\mu$m)', fontsize = 10)

ax4 = fig.add_subplot(122)

ax4.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 7)])

for i in range(1,7):
        plt.plot(new_data8[0:100,0],new_data8[0:100,i], lw = 2.5)
        
ax4.set_ylim([0,5])
ax4.set_xlabel('Electric field (V/$\mu$m)', fontsize = 10)

plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)

ax2.set_ylabel('J (A/m)', fontsize = 10)
#ax4.set_ylabel('J (A/m)', fontsize = 10)


plt.setp(ax2.get_xticklabels(), visible=True)
plt.setp(ax2.get_yticklabels(), visible=True)
plt.setp(ax4.get_yticklabels(), visible=False)
plt.setp(ax4.get_xticklabels(), visible=True)


ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')

ax4.xaxis.set_ticks_position('bottom')
ax4.yaxis.set_ticks_position('left')
ax2.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax4.spines['right'].set_visible(False)
ax4.spines['top'].set_visible(False)
major_ticks_1 = np.arange(0, 4.1, 1)   
ax4.set_xticks(major_ticks_1) 
ax2.set_xticks(major_ticks_1)
#ax3.set_xticks(major_ticks_1) 
#ax1.set_xticks(major_ticks_1)

plt.savefig("current_fields_saturation2.png",bbox_inches='tight', dpi = 300)
plt.show()
# Out:
# c:\users\jakub\anaconda3\lib\site-packages\matplotlib\cbook.py:137: MatplotlibDeprecationWarning: The set_color_cycle attribute was deprecated in version 1.5. Use set_prop_cycle instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
fig = plt.figure(figsize=(6,6))
fig.canvas.draw()
 
min, max = (2, 280)
step = 10
mymap = mpl.colors.LinearSegmentedColormap.from_list('mycolors',['blue','red'])
Z = [[0,0],[0,0]]
levels = range(min,max+step,step)

CS3 = plt.contourf(Z, levels, cmap='coolwarm', fontsize = 40)

plt.clf()  
cbaxes = fig.add_axes([1, 0.1, 0.03, 0.8]) 
cb = plt.colorbar(CS3, cax = cbaxes) 

opened_file = open("HRS_60V_gt_field.txt")
csv_data = csv.reader(opened_file, delimiter="\t")
parsed_data = []
for row in csv_data:
    parsed_data.append(row)
opened_file.close()
data = np.array(parsed_data)

opened_file4 = open("HRS_0V_gt_field.txt")
csv_data4 = csv.reader(opened_file4, delimiter="\t")
parsed_data4 = []
for row in csv_data4:
    parsed_data4.append(row)
opened_file4.close()
data4 = np.array(parsed_data4)

opened_file6 = open("LRS_0V_gt_field.txt")
csv_data6 = csv.reader(opened_file6, delimiter="\t")
parsed_data6 = []
for row in csv_data6:
    parsed_data6.append(row)
opened_file6.close()
data6 = np.array(parsed_data6)

opened_file8 = open("LRS_60V_gt_field.txt")
csv_data8 = csv.reader(opened_file8, delimiter="\t")
parsed_data8 = []
for row in csv_data8:
    parsed_data8.append(row)
opened_file8.close()
data8 = np.array(parsed_data8)

ax1 = fig.add_subplot(221)
colormap = plt.get_cmap('coolwarm')
ax1.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 14)])

for i in range(1,14):
        plt.plot(data[0:100,0],data[0:100,i], lw = 2)
        
ax1.set_ylim([0,0.001])
#ax1.set_xlabel('Gate bias (V)', fontsize = 15)
ax1.set_ylabel('J (A/m)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
#ax1.set_yscale('log')
ax1.set_xlim([0,1])
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax1.set_title('HRS @ V$_{g}$ = 0 V')

ax2 = fig.add_subplot(222)

ax2.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 14)])

for i in range(1,14):
        plt.plot(data4[0:100,0],data4[0:100,i], lw = 2)
        
ax2.set_ylim([0,1])
#ax2.set_xlabel('Gate bias (V)', fontsize = 15)
#ax2.set_ylabel('I$_{DS}$ (A)', fontsize = 15)
plt.ticklabel_format(style='sci', axis='y')
#ax2.set_yscale('log')
ax2.set_xlim([0,1])
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.set_title('HRS @ V$_{g}$ = 60 V')

ax3 = fig.add_subplot(223)

ax3.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 14)])

for i in range(1,14):
        plt.plot(data6[0:100,0],data6[0:100,i], lw = 2)
        
ax3.set_ylim([0,0.02])
ax3.set_xlim([0,1])
ax3.set_xlabel('Electric field (V/$\mu$m)', fontsize = 12)
ax3.set_ylabel('J (A/m)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
#ax3.set_yscale('log')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax3.set_title('LRS @ V$_{g}$ = 0 V')

ax4 = fig.add_subplot(224)

ax4.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 14)])

for i in range(1,14):
        plt.plot(data8[0:100,0],data8[0:100,i], lw = 2)
        
ax4.set_xlim([0,1])
ax4.set_ylim([0,1.5])
ax4.set_xlabel('Electric field (V/$\mu$m)', fontsize = 12)
#ax4.set_ylabel('I$_{DS}$ (A)', fontsize = 15)
plt.ticklabel_format(style='sci', axis='y')
#ax4.set_yscale('log')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax4.set_title('LRS @ V$_{g}$ = 60 V')

#ax1.set_ylabel('Conductance (S)', fontsize = 12)
#ax3.set_xlabel('Exposure time (s)', fontsize = 12)
#ax3.set_ylabel('Conductance (S)', fontsize = 12)
#ax4.set_xlabel('Exposure time (s)', fontsize = 12)

plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax3.get_xticklabels(), visible=True)
plt.setp(ax2.get_xticklabels(), visible=False)
plt.setp(ax2.get_yticklabels(), visible=True)
plt.setp(ax4.get_yticklabels(), visible=True)
plt.setp(ax4.get_xticklabels(), visible=True)

ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax3.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('left')
ax4.xaxis.set_ticks_position('bottom')
ax4.yaxis.set_ticks_position('left')

#major_ticks_1 = np.arange(-60, 61, 60)   
#ax4.set_xticks(major_ticks_1) 
#ax2.set_xticks(major_ticks_1)
#ax3.set_xticks(major_ticks_1) 
#ax1.set_xticks(major_ticks_1)

plt.savefig("zoom_low_fields.png",bbox_inches='tight', dpi = 300)
plt.show()
# Out:
# c:\users\jakub\anaconda3\lib\site-packages\matplotlib\cbook.py:137: MatplotlibDeprecationWarning: The set_color_cycle attribute was deprecated in version 1.5. Use set_prop_cycle instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
V_d = []
I_d = []

with open('device.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        V_d.append(float(row[0]))
        I_d.append(float(row[1]))

# %%
fig = plt.figure(figsize=(3.6,3.6))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)


# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax2.spines['left'].set_position('center')
ax2.spines['bottom'].set_position('center')
ax2.set_ylim([-0.0000006,0.0000006])
ax2.set_xlim([-20,20])
# Eliminate upper and right axes
ax2.spines['right'].set_color('none')
ax2.spines['top'].set_color('none')
yticks = [-6e-7,-4e-7,-2e-7,2e-7,4e-7,6e-7]
ax2.set_yticks(yticks)
xticks = [-20, -5, 5, 20]
ax2.set_xticks(xticks)
ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')

ax2.text(1, 5.9e-7, r'[$10^{-7}$ A]', fontsize=10)
ax2.text(-20, 0.5e-7, r'[V]', fontsize=10)

ax2.plot(V_d[0:50],I_d[0:50], '-', ms = 5,lw = 4, color = 'mediumblue')
ax2.plot(V_d[50:100],I_d[50:100], '-', ms = 5,lw = 4, alpha = 0.3, color = 'black')
ax2.plot(V_d[100:150],I_d[100:150], '-', ms = 5,lw = 4,alpha = 0.3,  color = 'black')
ax2.plot(V_d[150:200],I_d[150:200], '-', ms = 5,lw = 4, color = 'mediumblue')

plt.savefig("HRS_fog.jpg",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3.6,3.6))
fig.canvas.draw()
 
ax2 = fig.add_subplot(111)


# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax2.spines['left'].set_position('center')
ax2.spines['bottom'].set_position('center')
ax2.set_ylim([-0.0000006,0.0000006])
ax2.set_xlim([-20,20])
# Eliminate upper and right axes
ax2.spines['right'].set_color('none')
ax2.spines['top'].set_color('none')
ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
yticks = [-6e-7,-4e-7,-2e-7,2e-7,4e-7,6e-7]
ax2.set_yticks(yticks)
xticks = [-20, -5, 5, 20]
ax2.set_xticks(xticks)

ax2.text(1, 5.9e-7, r'[$10^{-7}$ A]', fontsize=10)
ax2.text(-20, 0.5e-7, r'[V]', fontsize=10)

ax2.plot(V_d[0:50],I_d[0:50], '-', ms = 5,lw = 4,alpha = 0.3, color = 'black')
ax2.plot(V_d[50:100],I_d[50:100], '-', ms = 5,lw = 4,  color = 'forestgreen')
ax2.plot(V_d[100:150],I_d[100:150], '-', ms = 5,lw = 4,  color = 'forestgreen')
ax2.plot(V_d[150:200],I_d[150:200], '-', ms = 5,lw = 4, alpha = 0.3,color = 'black')

plt.savefig("LRS_fog.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
n2Dnoises = pd.read_csv('same_n2D_noises.csv')
xLRSfit = n2Dnoises['x LRS fit']
LRSfit = n2Dnoises['LRS fit']
xHRSfit = n2Dnoises['x HRS fit']
HRSfit = n2Dnoises['HRS fit']
xLRS = n2Dnoises['x LRS']
LRS = n2Dnoises['LRS']
xHRS = n2Dnoises['x HRS']
HRS = n2Dnoises['HRS']

# %%
data = pd.read_csv("noisay.csv")

xfitHRS2 = data["xfitHRS"]
fitHRS2 = data["fitHRS"]
xfitLRS2 = data["xfitLRS"]
fitLRS2 = data["fitLRS"]
xLRS2 = data["xLRS"]
LRS2 = data["LRS"]
xHRS2 = data["xHRS"]
HRS2 = data["HRS"]

# %%
fig  =  plt.figure(figsize=(6,3))
fig.canvas.draw()

ax1 = fig.add_subplot(122)
ax1.plot(xHRS,HRS, '-', ms=3, color = 'mediumblue',  lw=0.5, alpha=0.7, mfc='purple') 
ax1.plot(xLRS,LRS, '-', ms=3, color = 'forestgreen',  lw=0.5, alpha=0.7, mfc='forestgreen') 
ax1.plot(xHRSfit,HRSfit, '-', ms=7, color = 'mediumblue',  lw=2, alpha=0.7, mfc='forestgreen', 
         dash_capstyle = 'butt', mew = '1' ) 
ax1.plot(xLRSfit,LRSfit, '-', ms=7, color = 'forestgreen',  lw=2, alpha=0.7, mfc='purple', 
         dash_capstyle = 'butt', mew = '1' ) 


ax1.set_xlabel('Frequency (Hz)', fontsize = 10)
#ax1.set_ylabel('S/I$^{2}$ (Hz$^{-1}$)', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
ax1.set_yscale('log')
ax1.set_xscale('log')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax1.text(0.3, 1e-5, r' $\beta$ = 1.00', fontsize = 10)
ax1.text(0.01, 1e-10, r' $\beta$ = 1.16', fontsize = 10)
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
ax1.set_xlim([0.001,5])

ax2 = fig.add_subplot(121)
ax2.plot(xHRS2,HRS2, '-', ms=3, color = 'forestgreen',  lw=0.5, alpha=0.7, mfc='purple') 
ax2.plot(xLRS2,LRS2, '-', ms=3, color = 'mediumblue',  lw=0.5, alpha=0.7, mfc='forestgreen') 
ax2.plot(xfitLRS2,fitLRS2, '-', ms=7, color = 'mediumblue',  lw=2, alpha=0.7, mfc='purple', 
         dash_capstyle = 'butt', mew = '1' ) 
ax2.plot(xfitHRS2,fitHRS2, '-', ms=7, color = 'forestgreen',  lw=2, alpha=0.7, mfc='forestgreen', 
         dash_capstyle = 'butt', mew = '1' ) 

ax2.set_xlabel('Frequency (Hz)', fontsize = 10)
ax2.set_ylabel('S/I$^{2}$ (Hz$^{-1}$)', fontsize = 10)
plt.ticklabel_format(style='sci', axis='y')
ax2.set_yscale('log')
ax2.set_xscale('log')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
ax2.text(0.5, 1e-5, r' $\beta$ = 1.07', fontsize = 10)
ax2.text(0.01, 1e-10, r' $\beta$ = 1.03', fontsize = 10)
ax2.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.set_xlim([0.001,11])

plt.setp(ax2.get_xticklabels(), visible=True)
plt.setp(ax2.get_yticklabels(), visible=True)
plt.setp(ax1.get_yticklabels(), visible=False)
plt.setp(ax1.get_xticklabels(), visible=True)

for label in ax2.yaxis.get_ticklabels()[::2]:
    label.set_visible(False)
    
plt.savefig("both_noises.png",bbox_inches='tight', dpi = 300)
plt.show()

# %%
lnW_LRS = [3.43E+00,
2.59E+00,
2.36E+00,
2.11E+00,
2.00E+00,
1.83E+00,
1.66E+00,
1.44E+00,
1.26E+00,
1.16E+00,
1.10E+00,
1.05E+00,
1.00E+00,
9.59E-01]

lnW_HRS = [3.47E+00,
2.63E+00,
2.40E+00,
2.15E+00,
2.04E+00,
1.86E+00,
1.69E+00,
1.47E+00,
1.28E+00,
1.18E+00,
1.11E+00,
1.07E+00,
1.02E+00,
9.42E-01]


lnT = [0.470003629,
1.098612289,
1.386294361,
1.774952351,
1.987874348,
2.351375257,
2.772588722,
3.465735903,
4.158883083,
4.564348191,
4.852030264,
5.075173815,
5.298317367,
5.634789603
]

# %%
fig = plt.figure(figsize=(3.5,3.5))
fig.canvas.draw()
 
ax1 = fig.add_subplot(111)
plt.plot(lnT,lnW_LRS, 's',ms = 8,mew = 0.55,alpha = 1,  lw = 1, color = 'forestgreen', label = 'LRS')
plt.plot(lnT,lnW_HRS, 'd',ms = 8,mew = 0.55,alpha = 0.7,  lw = 1, color = 'dodgerblue', label = 'HRS')

#ax1.set_ylim([1e5,1e9])
#ax1.set_xlim([1,320])
ax1.set_xlabel('ln T', fontsize = 12)
ax1.set_ylabel('ln W', fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')
plt.yticks(fontsize = 10)
plt.xticks(fontsize = 10)
#ax1.set_title('V$_{g}$ = 0 V')
#ax1.set_xscale('log')
#ax1.set_yscale('log')
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
ax1.legend(loc = 'best', fontsize = 8, ncol =2)

plt.tight_layout()
plt.savefig("lnWs.png",bbox_inches='tight', dpi = 300)
plt.show()
